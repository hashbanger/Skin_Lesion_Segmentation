# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('../input/*/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('../input/*/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# #### Jaccard Distance
# The Jaccard distance, which measures dissimilarity between sample sets, is complementary to the Jaccard coefficient and is obtained by subtracting the Jaccard coefficient from 1, or, equivalently, by dividing the difference of the sizes of the union and the intersection of two sets by the size of the union:

# %% [markdown]
# ![jd](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-44046533fcd54e98cb53619b3390e083_l3.svg)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
def img_augmentation(x_test, y_test):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_test)):
        x,y = random_rotation(x_test[idx], y_test[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_test[idx], y_test[idx])
        x_flip.append(x)
        y_flip.append(y)

    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 114
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt adam optimization algorithm or adaptive moments, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * Advantages of Adam optimizer are:
#     - Relatively low memory requirements (though higher than gradient descent and gradient descent with momentum).
#     - Usually works well even with a little tuning of hyperparameter
# * Adam is fairly robust to the choice of hyperparameters, and set the learning rate **α** as 0.003 to speed up the training procedure in this study as advised in the paper [here](https://arxiv.org/pdf/1703.05165v2.pdf)

# %% [markdown]
# ### Model Function

# %% [markdown]
# ![arch](https://raw.githubusercontent.com/hashbanger/Skin_Lesion_Segmentation/master/graphics/fcn_arch.png)

# %%
def fcn_net(epochs_num,savename):

    # Convolution Layers (BatchNorm after non-linear activation)

    img_input = Input(shape= (192, 256, 3))
    x = Conv2D(16, (5, 5), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    x = Conv2D(64, (4, 4), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (4, 4), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Dropout(0.5)(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)

    # Deconvolution Layers (BatchNorm after non-linear activation)

    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = UpSampling2D()(x)
    x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn9')(x)
    
    x = Dropout(0.5)(x)

    x = Activation('sigmoid')(x)
    pred = Reshape((192,256))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])

    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)

    model.save(savename)
    return model,hist

# %% [markdown]
# <font color='red'>**Problems In Guided Dropout Implementation**
#
# - The entire network architecture is implemented using Keras.
# - Now to implement the Guided Dropout Layer using Keras we have to know the detailed backend of the Keras Library because:
# - We should know in what form the inputs will be coming to our layer so we could manipulate them.
# - We should also know in what form the output should be given to the next layer.
# - If we implement Guided Dropout from scratch then we will have to implement entire architecture from scratch which will be neither efficient nor easily feasible.</font>

# %% [markdown]
# **After 1 epoch**

# %%
model, hist = fcn_net(epochs_num= 1, savename= 'fcn_1_epochs.h5')
# Out:
# Train on 360 samples, validate on 90 samples
# Epoch 1/1
# 360/360 [==============================] - 13s 37ms/step - loss: 0.2718 - iou: 0.7282 - dice_coef: 0.4778 - precision: 0.6617 - recall: 0.3432 - accuracy: 0.7258 - val_loss: 0.4832 - val_iou: 0.5168 - val_dice_coef: 0.4818 - val_precision: 0.3144 - val_recall: 1.0000 - val_accuracy: 0.3163

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
img_input = Input(shape= (192, 256, 3))
x = Conv2D(16, (5, 5), padding='same', name='conv1',strides= (1,1))(img_input)
x = BatchNormalization(name='bn1')(x)
x = Activation('relu')(x)
x = Conv2D(32, (3, 3), padding='same', name='conv2')(x)
x = BatchNormalization(name='bn2')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)
x = Conv2D(64, (4, 4), padding='same', name='conv3')(x)
x = BatchNormalization(name='bn3')(x)
x = Activation('relu')(x)
x = Conv2D(64, (4, 4), padding='same', name='conv4')(x)
x = BatchNormalization(name='bn4')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Dropout(0.5)(x)

x = Conv2D(512, (3, 3), padding='same', name='conv5')(x)
x = BatchNormalization(name='bn5')(x)
x = Activation('relu')(x)
x = Dense(1024, activation = 'relu', name='fc1')(x)
x = Dense(1024, activation = 'relu', name='fc2')(x)

# Deconvolution Layers (BatchNorm after non-linear activation)

x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv1')(x)
x = BatchNormalization(name='bn6')(x)
x = Activation('relu')(x)
x = UpSampling2D()(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv2')(x)
x = BatchNormalization(name='bn7')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv3')(x)
x = BatchNormalization(name='bn8')(x)
x = Activation('relu')(x)
x = UpSampling2D()(x)
x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv4')(x)
x = BatchNormalization(name='bn9')(x)

x = Dropout(0.5)(x)

x = Activation('sigmoid')(x)
pred = Reshape((192,256))(x)

# %%
model_0 = Model(inputs=img_input, outputs=pred)
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance], metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_0.load_weights('fcn_1_epochs.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 8ms/step
# ________________________
# IOU:       |   52.40  |
# Dice Coef: |   49.07  |
# Precision: |   32.42  |
# Recall:    |   99.99  |
# Accuracy:  |   32.65  |
# Loss:      |   47.60  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 14ms/step
# ________________________
# IOU:       |   51.68  |
# Dice Coef: |   48.17  |
# Precision: |   31.48  |
# Recall:    |   100.00  |
# Accuracy:  |   31.71  |
# Loss:      |   48.32  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   51.68  |
# Dice Coef: |   48.18  |
# Precision: |   31.44  |
# Recall:    |   100.00  |
# Accuracy:  |   31.63  |
# Loss:      |   48.32  |
# ________________________

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = fcn_net(epochs_num= 100, savename= 'fcn_100_epoch.h5')
# Out:
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 10s 28ms/step - loss: 0.2636 - iou: 0.7364 - dice_coef: 0.4977 - precision: 0.6938 - recall: 0.3960 - accuracy: 0.7309 - val_loss: 0.2151 - val_iou: 0.7849 - val_dice_coef: 0.6587 - val_precision: 0.5638 - val_recall: 0.8635 - val_accuracy: 0.7481
# Epoch 2/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2334 - iou: 0.7666 - dice_coef: 0.5346 - precision: 0.8340 - recall: 0.4132 - accuracy: 0.7822 - val_loss: 0.1665 - val_iou: 0.8335 - val_dice_coef: 0.5610 - val_precision: 0.9683 - val_recall: 0.4554 - val_accuracy: 0.8260
# Epoch 3/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2311 - iou: 0.7689 - dice_coef: 0.5362 - precision: 0.8527 - recall: 0.4027 - accuracy: 0.7837 - val_loss: 0.2756 - val_iou: 0.7244 - val_dice_coef: 0.5747 - val_precision: 0.4690 - val_recall: 0.9394 - val_accuracy: 0.6506
# Epoch 4/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2312 - iou: 0.7688 - dice_coef: 0.5371 - precision: 0.8424 - recall: 0.4044 - accuracy: 0.7814 - val_loss: 0.4503 - val_iou: 0.5497 - val_dice_coef: 0.5030 - val_precision: 0.3348 - val_recall: 0.9982 - val_accuracy: 0.3781
# Epoch 5/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2273 - iou: 0.7727 - dice_coef: 0.5448 - precision: 0.8545 - recall: 0.4091 - accuracy: 0.7853 - val_loss: 0.4317 - val_iou: 0.5683 - val_dice_coef: 0.4365 - val_precision: 0.3090 - val_recall: 0.7598 - val_accuracy: 0.3933
# Epoch 6/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2267 - iou: 0.7733 - dice_coef: 0.5474 - precision: 0.8544 - recall: 0.4062 - accuracy: 0.7851 - val_loss: 0.2617 - val_iou: 0.7383 - val_dice_coef: 0.3216 - val_precision: 0.9234 - val_recall: 0.1696 - val_accuracy: 0.7359
# Epoch 7/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2248 - iou: 0.7752 - dice_coef: 0.5471 - precision: 0.8727 - recall: 0.4059 - accuracy: 0.7866 - val_loss: 0.2403 - val_iou: 0.7597 - val_dice_coef: 0.4654 - val_precision: 0.5644 - val_recall: 0.6971 - val_accuracy: 0.7407
# Epoch 8/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2226 - iou: 0.7774 - dice_coef: 0.5554 - precision: 0.8661 - recall: 0.4163 - accuracy: 0.7896 - val_loss: 0.2725 - val_iou: 0.7275 - val_dice_coef: 0.2520 - val_precision: 0.9949 - val_recall: 0.0643 - val_accuracy: 0.7076
# Epoch 9/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2215 - iou: 0.7785 - dice_coef: 0.5553 - precision: 0.8742 - recall: 0.4149 - accuracy: 0.7904 - val_loss: 0.2032 - val_iou: 0.7968 - val_dice_coef: 0.4458 - val_precision: 0.9860 - val_recall: 0.2967 - val_accuracy: 0.7790
# Epoch 10/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2286 - iou: 0.7714 - dice_coef: 0.5495 - precision: 0.8288 - recall: 0.4111 - accuracy: 0.7800 - val_loss: 0.2830 - val_iou: 0.7170 - val_dice_coef: 0.5992 - val_precision: 0.4672 - val_recall: 0.9900 - val_accuracy: 0.6449
# Epoch 11/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2229 - iou: 0.7771 - dice_coef: 0.5559 - precision: 0.8697 - recall: 0.4120 - accuracy: 0.7886 - val_loss: 0.3595 - val_iou: 0.6405 - val_dice_coef: 0.5541 - val_precision: 0.3929 - val_recall: 0.9926 - val_accuracy: 0.5193
# Epoch 12/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2210 - iou: 0.7790 - dice_coef: 0.5584 - precision: 0.8734 - recall: 0.4136 - accuracy: 0.7897 - val_loss: 0.2843 - val_iou: 0.7157 - val_dice_coef: 0.5715 - val_precision: 0.4488 - val_recall: 0.9428 - val_accuracy: 0.6227
# Epoch 13/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2184 - iou: 0.7816 - dice_coef: 0.5649 - precision: 0.8659 - recall: 0.4290 - accuracy: 0.7923 - val_loss: 0.2434 - val_iou: 0.7566 - val_dice_coef: 0.6016 - val_precision: 0.5031 - val_recall: 0.9488 - val_accuracy: 0.6929
# Epoch 14/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2173 - iou: 0.7827 - dice_coef: 0.5673 - precision: 0.8848 - recall: 0.4223 - accuracy: 0.7945 - val_loss: 0.2164 - val_iou: 0.7836 - val_dice_coef: 0.5817 - val_precision: 0.5631 - val_recall: 0.8831 - val_accuracy: 0.7480
# Epoch 15/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2181 - iou: 0.7819 - dice_coef: 0.5663 - precision: 0.8733 - recall: 0.4249 - accuracy: 0.7928 - val_loss: 0.2794 - val_iou: 0.7206 - val_dice_coef: 0.5892 - val_precision: 0.4783 - val_recall: 0.9673 - val_accuracy: 0.6612
# Epoch 16/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2155 - iou: 0.7845 - dice_coef: 0.5732 - precision: 0.8912 - recall: 0.4252 - accuracy: 0.7966 - val_loss: 0.2361 - val_iou: 0.7639 - val_dice_coef: 0.5904 - val_precision: 0.5308 - val_recall: 0.9380 - val_accuracy: 0.7219
# Epoch 17/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2151 - iou: 0.7849 - dice_coef: 0.5730 - precision: 0.8786 - recall: 0.4311 - accuracy: 0.7965 - val_loss: 0.1120 - val_iou: 0.8880 - val_dice_coef: 0.6650 - val_precision: 0.8844 - val_recall: 0.8408 - val_accuracy: 0.9159
# Epoch 18/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2128 - iou: 0.7872 - dice_coef: 0.5771 - precision: 0.8943 - recall: 0.4319 - accuracy: 0.7992 - val_loss: 0.1401 - val_iou: 0.8599 - val_dice_coef: 0.6414 - val_precision: 0.7680 - val_recall: 0.8736 - val_accuracy: 0.8760
# Epoch 19/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2123 - iou: 0.7877 - dice_coef: 0.5783 - precision: 0.8978 - recall: 0.4307 - accuracy: 0.7999 - val_loss: 0.1342 - val_iou: 0.8658 - val_dice_coef: 0.6733 - val_precision: 0.7649 - val_recall: 0.9421 - val_accuracy: 0.8908
# Epoch 20/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2132 - iou: 0.7868 - dice_coef: 0.5787 - precision: 0.8866 - recall: 0.4339 - accuracy: 0.7988 - val_loss: 0.2105 - val_iou: 0.7895 - val_dice_coef: 0.5724 - val_precision: 0.5973 - val_recall: 0.8051 - val_accuracy: 0.7653
# Epoch 21/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2173 - iou: 0.7827 - dice_coef: 0.5715 - precision: 0.8798 - recall: 0.4234 - accuracy: 0.7934 - val_loss: 0.1767 - val_iou: 0.8233 - val_dice_coef: 0.4780 - val_precision: 0.9878 - val_recall: 0.3832 - val_accuracy: 0.8044
# Epoch 22/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2171 - iou: 0.7829 - dice_coef: 0.5702 - precision: 0.8834 - recall: 0.4206 - accuracy: 0.7939 - val_loss: 0.1876 - val_iou: 0.8124 - val_dice_coef: 0.5168 - val_precision: 0.7977 - val_recall: 0.5124 - val_accuracy: 0.8048
# Epoch 23/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2112 - iou: 0.7888 - dice_coef: 0.5816 - precision: 0.8960 - recall: 0.4367 - accuracy: 0.8011 - val_loss: 0.1933 - val_iou: 0.8067 - val_dice_coef: 0.4643 - val_precision: 0.9884 - val_recall: 0.3655 - val_accuracy: 0.7999
# Epoch 24/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2098 - iou: 0.7902 - dice_coef: 0.5864 - precision: 0.9014 - recall: 0.4390 - accuracy: 0.8027 - val_loss: 0.1583 - val_iou: 0.8417 - val_dice_coef: 0.6404 - val_precision: 0.7362 - val_recall: 0.8552 - val_accuracy: 0.8549
# Epoch 25/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2150 - iou: 0.7850 - dice_coef: 0.5741 - precision: 0.8936 - recall: 0.4271 - accuracy: 0.7957 - val_loss: 0.1367 - val_iou: 0.8633 - val_dice_coef: 0.6632 - val_precision: 0.7110 - val_recall: 0.9456 - val_accuracy: 0.8622
# Epoch 26/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2148 - iou: 0.7852 - dice_coef: 0.5775 - precision: 0.8848 - recall: 0.4313 - accuracy: 0.7970 - val_loss: 0.1251 - val_iou: 0.8749 - val_dice_coef: 0.7102 - val_precision: 0.7635 - val_recall: 0.9407 - val_accuracy: 0.8909
# Epoch 27/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2110 - iou: 0.7890 - dice_coef: 0.5825 - precision: 0.9000 - recall: 0.4336 - accuracy: 0.8011 - val_loss: 0.1751 - val_iou: 0.8249 - val_dice_coef: 0.4991 - val_precision: 0.8993 - val_recall: 0.4173 - val_accuracy: 0.8008
# Epoch 28/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2119 - iou: 0.7881 - dice_coef: 0.5829 - precision: 0.8870 - recall: 0.4387 - accuracy: 0.7995 - val_loss: 0.1169 - val_iou: 0.8831 - val_dice_coef: 0.6578 - val_precision: 0.9228 - val_recall: 0.7159 - val_accuracy: 0.8930
# Epoch 29/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2141 - iou: 0.7859 - dice_coef: 0.5775 - precision: 0.8905 - recall: 0.4286 - accuracy: 0.7969 - val_loss: 0.1705 - val_iou: 0.8295 - val_dice_coef: 0.5447 - val_precision: 0.8598 - val_recall: 0.5100 - val_accuracy: 0.8206
# Epoch 30/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2138 - iou: 0.7862 - dice_coef: 0.5768 - precision: 0.8922 - recall: 0.4294 - accuracy: 0.7975 - val_loss: 0.1135 - val_iou: 0.8865 - val_dice_coef: 0.6995 - val_precision: 0.8257 - val_recall: 0.8484 - val_accuracy: 0.8960
# Epoch 31/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2099 - iou: 0.7901 - dice_coef: 0.5853 - precision: 0.8990 - recall: 0.4407 - accuracy: 0.8025 - val_loss: 0.1586 - val_iou: 0.8414 - val_dice_coef: 0.6677 - val_precision: 0.7283 - val_recall: 0.8587 - val_accuracy: 0.8549
# Epoch 32/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2095 - iou: 0.7905 - dice_coef: 0.5843 - precision: 0.9122 - recall: 0.4338 - accuracy: 0.8030 - val_loss: 0.1304 - val_iou: 0.8696 - val_dice_coef: 0.6765 - val_precision: 0.7572 - val_recall: 0.9023 - val_accuracy: 0.8794
# Epoch 33/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2086 - iou: 0.7914 - dice_coef: 0.5885 - precision: 0.8987 - recall: 0.4456 - accuracy: 0.8041 - val_loss: 0.1524 - val_iou: 0.8476 - val_dice_coef: 0.6970 - val_precision: 0.7067 - val_recall: 0.9604 - val_accuracy: 0.8635
# Epoch 34/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2071 - iou: 0.7929 - dice_coef: 0.5901 - precision: 0.9225 - recall: 0.4365 - accuracy: 0.8058 - val_loss: 0.1789 - val_iou: 0.8211 - val_dice_coef: 0.6157 - val_precision: 0.6946 - val_recall: 0.8376 - val_accuracy: 0.8308
# Epoch 35/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2108 - iou: 0.7892 - dice_coef: 0.5831 - precision: 0.9033 - recall: 0.4333 - accuracy: 0.8013 - val_loss: 0.1142 - val_iou: 0.8858 - val_dice_coef: 0.6923 - val_precision: 0.8067 - val_recall: 0.8828 - val_accuracy: 0.8960
# Epoch 36/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2089 - iou: 0.7911 - dice_coef: 0.5885 - precision: 0.8965 - recall: 0.4442 - accuracy: 0.8033 - val_loss: 0.1387 - val_iou: 0.8613 - val_dice_coef: 0.6292 - val_precision: 0.8460 - val_recall: 0.6939 - val_accuracy: 0.8647
# Epoch 37/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2063 - iou: 0.7937 - dice_coef: 0.5914 - precision: 0.9182 - recall: 0.4437 - accuracy: 0.8068 - val_loss: 0.2009 - val_iou: 0.7991 - val_dice_coef: 0.4425 - val_precision: 0.9533 - val_recall: 0.3154 - val_accuracy: 0.7786
# Epoch 38/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2044 - iou: 0.7956 - dice_coef: 0.5979 - precision: 0.9257 - recall: 0.4465 - accuracy: 0.8095 - val_loss: 0.1703 - val_iou: 0.8297 - val_dice_coef: 0.5644 - val_precision: 0.7902 - val_recall: 0.6910 - val_accuracy: 0.8450
# Epoch 39/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2101 - iou: 0.7899 - dice_coef: 0.5872 - precision: 0.9009 - recall: 0.4394 - accuracy: 0.8013 - val_loss: 0.1174 - val_iou: 0.8826 - val_dice_coef: 0.6957 - val_precision: 0.8269 - val_recall: 0.8686 - val_accuracy: 0.9021
# Epoch 40/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2094 - iou: 0.7906 - dice_coef: 0.5876 - precision: 0.9077 - recall: 0.4360 - accuracy: 0.8030 - val_loss: 0.0784 - val_iou: 0.9216 - val_dice_coef: 0.7520 - val_precision: 0.9100 - val_recall: 0.8841 - val_accuracy: 0.9349
# Epoch 41/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2062 - iou: 0.7938 - dice_coef: 0.5957 - precision: 0.9117 - recall: 0.4485 - accuracy: 0.8070 - val_loss: 0.1826 - val_iou: 0.8174 - val_dice_coef: 0.6237 - val_precision: 0.6515 - val_recall: 0.8180 - val_accuracy: 0.8017
# Epoch 42/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2054 - iou: 0.7946 - dice_coef: 0.5925 - precision: 0.9244 - recall: 0.4442 - accuracy: 0.8079 - val_loss: 0.0873 - val_iou: 0.9127 - val_dice_coef: 0.7258 - val_precision: 0.8579 - val_recall: 0.9238 - val_accuracy: 0.9270
# Epoch 43/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2055 - iou: 0.7945 - dice_coef: 0.5961 - precision: 0.9210 - recall: 0.4451 - accuracy: 0.8079 - val_loss: 0.1224 - val_iou: 0.8776 - val_dice_coef: 0.6889 - val_precision: 0.7443 - val_recall: 0.9633 - val_accuracy: 0.8852
# Epoch 44/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2035 - iou: 0.7965 - dice_coef: 0.5989 - precision: 0.9189 - recall: 0.4534 - accuracy: 0.8103 - val_loss: 0.1615 - val_iou: 0.8385 - val_dice_coef: 0.6492 - val_precision: 0.6921 - val_recall: 0.9542 - val_accuracy: 0.8515
# Epoch 45/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2056 - iou: 0.7944 - dice_coef: 0.5931 - precision: 0.9168 - recall: 0.4473 - accuracy: 0.8071 - val_loss: 0.1934 - val_iou: 0.8066 - val_dice_coef: 0.6315 - val_precision: 0.6096 - val_recall: 0.9676 - val_accuracy: 0.7950
# Epoch 46/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2044 - iou: 0.7956 - dice_coef: 0.5977 - precision: 0.9160 - recall: 0.4515 - accuracy: 0.8087 - val_loss: 0.1183 - val_iou: 0.8817 - val_dice_coef: 0.6350 - val_precision: 0.9499 - val_recall: 0.7101 - val_accuracy: 0.8953
# Epoch 47/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2055 - iou: 0.7945 - dice_coef: 0.5950 - precision: 0.9269 - recall: 0.4433 - accuracy: 0.8079 - val_loss: 0.2290 - val_iou: 0.7710 - val_dice_coef: 0.6178 - val_precision: 0.5188 - val_recall: 0.9944 - val_accuracy: 0.7108
# Epoch 48/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2038 - iou: 0.7962 - dice_coef: 0.5996 - precision: 0.9209 - recall: 0.4513 - accuracy: 0.8098 - val_loss: 0.1251 - val_iou: 0.8749 - val_dice_coef: 0.7094 - val_precision: 0.7341 - val_recall: 0.9624 - val_accuracy: 0.8781
# Epoch 49/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2019 - iou: 0.7981 - dice_coef: 0.6036 - precision: 0.9252 - recall: 0.4551 - accuracy: 0.8119 - val_loss: 0.1470 - val_iou: 0.8530 - val_dice_coef: 0.6477 - val_precision: 0.8115 - val_recall: 0.8958 - val_accuracy: 0.9004
# Epoch 50/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2015 - iou: 0.7985 - dice_coef: 0.6023 - precision: 0.9334 - recall: 0.4529 - accuracy: 0.8126 - val_loss: 0.2204 - val_iou: 0.7796 - val_dice_coef: 0.6130 - val_precision: 0.5263 - val_recall: 0.9865 - val_accuracy: 0.7189
# Epoch 51/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2014 - iou: 0.7986 - dice_coef: 0.6054 - precision: 0.9218 - recall: 0.4590 - accuracy: 0.8125 - val_loss: 0.1559 - val_iou: 0.8441 - val_dice_coef: 0.6773 - val_precision: 0.6710 - val_recall: 0.9654 - val_accuracy: 0.8415
# Epoch 52/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2009 - iou: 0.7991 - dice_coef: 0.6043 - precision: 0.9361 - recall: 0.4538 - accuracy: 0.8131 - val_loss: 0.0808 - val_iou: 0.9192 - val_dice_coef: 0.7246 - val_precision: 0.9147 - val_recall: 0.9102 - val_accuracy: 0.9436
# Epoch 53/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1999 - iou: 0.8001 - dice_coef: 0.6066 - precision: 0.9333 - recall: 0.4593 - accuracy: 0.8141 - val_loss: 0.1124 - val_iou: 0.8876 - val_dice_coef: 0.7044 - val_precision: 0.8007 - val_recall: 0.9531 - val_accuracy: 0.9101
# Epoch 54/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2004 - iou: 0.7996 - dice_coef: 0.6059 - precision: 0.9258 - recall: 0.4617 - accuracy: 0.8137 - val_loss: 0.1189 - val_iou: 0.8811 - val_dice_coef: 0.7057 - val_precision: 0.7666 - val_recall: 0.9420 - val_accuracy: 0.8900
# Epoch 55/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2029 - iou: 0.7971 - dice_coef: 0.6005 - precision: 0.9233 - recall: 0.4512 - accuracy: 0.8103 - val_loss: 0.0839 - val_iou: 0.9161 - val_dice_coef: 0.7468 - val_precision: 0.9008 - val_recall: 0.8667 - val_accuracy: 0.9279
# Epoch 56/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2040 - iou: 0.7960 - dice_coef: 0.5996 - precision: 0.9183 - recall: 0.4496 - accuracy: 0.8090 - val_loss: 0.0984 - val_iou: 0.9016 - val_dice_coef: 0.7352 - val_precision: 0.8135 - val_recall: 0.9087 - val_accuracy: 0.9061
# Epoch 57/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2025 - iou: 0.7975 - dice_coef: 0.6012 - precision: 0.9278 - recall: 0.4521 - accuracy: 0.8110 - val_loss: 0.1056 - val_iou: 0.8944 - val_dice_coef: 0.7073 - val_precision: 0.7947 - val_recall: 0.8683 - val_accuracy: 0.8896
# Epoch 58/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2021 - iou: 0.7979 - dice_coef: 0.6031 - precision: 0.9218 - recall: 0.4573 - accuracy: 0.8116 - val_loss: 0.1285 - val_iou: 0.8715 - val_dice_coef: 0.7177 - val_precision: 0.7320 - val_recall: 0.9743 - val_accuracy: 0.8791
# Epoch 59/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2027 - iou: 0.7973 - dice_coef: 0.6015 - precision: 0.9297 - recall: 0.4499 - accuracy: 0.8108 - val_loss: 0.0963 - val_iou: 0.9037 - val_dice_coef: 0.7320 - val_precision: 0.8708 - val_recall: 0.9177 - val_accuracy: 0.9299
# Epoch 60/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2029 - iou: 0.7971 - dice_coef: 0.6020 - precision: 0.9115 - recall: 0.4590 - accuracy: 0.8103 - val_loss: 0.1173 - val_iou: 0.8827 - val_dice_coef: 0.7373 - val_precision: 0.7377 - val_recall: 0.9679 - val_accuracy: 0.8810
# Epoch 61/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2011 - iou: 0.7989 - dice_coef: 0.6043 - precision: 0.9302 - recall: 0.4557 - accuracy: 0.8126 - val_loss: 0.0878 - val_iou: 0.9122 - val_dice_coef: 0.7262 - val_precision: 0.8790 - val_recall: 0.8989 - val_accuracy: 0.9285
# Epoch 62/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2010 - iou: 0.7990 - dice_coef: 0.6047 - precision: 0.9349 - recall: 0.4552 - accuracy: 0.8133 - val_loss: 0.3299 - val_iou: 0.6701 - val_dice_coef: 0.5505 - val_precision: 0.4084 - val_recall: 0.9533 - val_accuracy: 0.5540
# Epoch 63/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2018 - iou: 0.7982 - dice_coef: 0.6059 - precision: 0.9199 - recall: 0.4582 - accuracy: 0.8117 - val_loss: 0.1206 - val_iou: 0.8794 - val_dice_coef: 0.7077 - val_precision: 0.7894 - val_recall: 0.8554 - val_accuracy: 0.8787
# Epoch 64/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2009 - iou: 0.7991 - dice_coef: 0.6051 - precision: 0.9300 - recall: 0.4573 - accuracy: 0.8129 - val_loss: 0.1308 - val_iou: 0.8692 - val_dice_coef: 0.7104 - val_precision: 0.7155 - val_recall: 0.9786 - val_accuracy: 0.8713
# Epoch 65/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1989 - iou: 0.8011 - dice_coef: 0.6094 - precision: 0.9342 - recall: 0.4622 - accuracy: 0.8154 - val_loss: 0.0751 - val_iou: 0.9249 - val_dice_coef: 0.7380 - val_precision: 0.9269 - val_recall: 0.9164 - val_accuracy: 0.9497
# Epoch 66/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1992 - iou: 0.8008 - dice_coef: 0.6057 - precision: 0.9373 - recall: 0.4590 - accuracy: 0.8149 - val_loss: 0.0818 - val_iou: 0.9182 - val_dice_coef: 0.7514 - val_precision: 0.8598 - val_recall: 0.8992 - val_accuracy: 0.9206
# Epoch 67/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2003 - iou: 0.7997 - dice_coef: 0.6056 - precision: 0.9272 - recall: 0.4599 - accuracy: 0.8136 - val_loss: 0.0916 - val_iou: 0.9084 - val_dice_coef: 0.7465 - val_precision: 0.8259 - val_recall: 0.9338 - val_accuracy: 0.9162
# Epoch 68/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1984 - iou: 0.8016 - dice_coef: 0.6119 - precision: 0.9346 - recall: 0.4637 - accuracy: 0.8158 - val_loss: 0.1071 - val_iou: 0.8929 - val_dice_coef: 0.7308 - val_precision: 0.7853 - val_recall: 0.9440 - val_accuracy: 0.9007
# Epoch 69/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2004 - iou: 0.7996 - dice_coef: 0.6078 - precision: 0.9371 - recall: 0.4555 - accuracy: 0.8135 - val_loss: 0.0925 - val_iou: 0.9075 - val_dice_coef: 0.7529 - val_precision: 0.8065 - val_recall: 0.9152 - val_accuracy: 0.9033
# Epoch 70/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1998 - iou: 0.8002 - dice_coef: 0.6096 - precision: 0.9295 - recall: 0.4611 - accuracy: 0.8144 - val_loss: 0.0729 - val_iou: 0.9271 - val_dice_coef: 0.7749 - val_precision: 0.9053 - val_recall: 0.9103 - val_accuracy: 0.9408
# Epoch 71/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1981 - iou: 0.8019 - dice_coef: 0.6127 - precision: 0.9391 - recall: 0.4605 - accuracy: 0.8162 - val_loss: 0.1249 - val_iou: 0.8751 - val_dice_coef: 0.7054 - val_precision: 0.7650 - val_recall: 0.9436 - val_accuracy: 0.8901
# Epoch 72/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1998 - iou: 0.8002 - dice_coef: 0.6074 - precision: 0.9276 - recall: 0.4625 - accuracy: 0.8145 - val_loss: 0.0918 - val_iou: 0.9082 - val_dice_coef: 0.7480 - val_precision: 0.8435 - val_recall: 0.9327 - val_accuracy: 0.9233
# Epoch 73/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1988 - iou: 0.8012 - dice_coef: 0.6117 - precision: 0.9420 - recall: 0.4580 - accuracy: 0.8156 - val_loss: 0.0866 - val_iou: 0.9134 - val_dice_coef: 0.7527 - val_precision: 0.8486 - val_recall: 0.9467 - val_accuracy: 0.9288
# Epoch 74/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1993 - iou: 0.8007 - dice_coef: 0.6093 - precision: 0.9281 - recall: 0.4624 - accuracy: 0.8148 - val_loss: 0.2352 - val_iou: 0.7648 - val_dice_coef: 0.6198 - val_precision: 0.5258 - val_recall: 0.9641 - val_accuracy: 0.7169
# Epoch 75/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1973 - iou: 0.8027 - dice_coef: 0.6130 - precision: 0.9398 - recall: 0.4643 - accuracy: 0.8175 - val_loss: 0.1767 - val_iou: 0.8233 - val_dice_coef: 0.6138 - val_precision: 0.6627 - val_recall: 0.7924 - val_accuracy: 0.8093
# Epoch 76/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1992 - iou: 0.8008 - dice_coef: 0.6092 - precision: 0.9339 - recall: 0.4617 - accuracy: 0.8149 - val_loss: 0.0985 - val_iou: 0.9015 - val_dice_coef: 0.7389 - val_precision: 0.7990 - val_recall: 0.9341 - val_accuracy: 0.9045
# Epoch 77/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1994 - iou: 0.8006 - dice_coef: 0.6093 - precision: 0.9386 - recall: 0.4576 - accuracy: 0.8148 - val_loss: 0.0944 - val_iou: 0.9056 - val_dice_coef: 0.7090 - val_precision: 0.9431 - val_recall: 0.7603 - val_accuracy: 0.9085
# Epoch 78/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1986 - iou: 0.8014 - dice_coef: 0.6139 - precision: 0.9344 - recall: 0.4621 - accuracy: 0.8156 - val_loss: 0.1686 - val_iou: 0.8314 - val_dice_coef: 0.6868 - val_precision: 0.6129 - val_recall: 0.9755 - val_accuracy: 0.7980
# Epoch 79/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1984 - iou: 0.8016 - dice_coef: 0.6124 - precision: 0.9304 - recall: 0.4639 - accuracy: 0.8157 - val_loss: 0.2347 - val_iou: 0.7653 - val_dice_coef: 0.6410 - val_precision: 0.5206 - val_recall: 0.9840 - val_accuracy: 0.7127
# Epoch 80/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1982 - iou: 0.8018 - dice_coef: 0.6120 - precision: 0.9393 - recall: 0.4618 - accuracy: 0.8161 - val_loss: 0.1583 - val_iou: 0.8417 - val_dice_coef: 0.6791 - val_precision: 0.6577 - val_recall: 0.9523 - val_accuracy: 0.8289
# Epoch 81/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1983 - iou: 0.8017 - dice_coef: 0.6097 - precision: 0.9354 - recall: 0.4633 - accuracy: 0.8160 - val_loss: 0.1116 - val_iou: 0.8884 - val_dice_coef: 0.7204 - val_precision: 0.8099 - val_recall: 0.9419 - val_accuracy: 0.9116
# Epoch 82/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1994 - iou: 0.8006 - dice_coef: 0.6073 - precision: 0.9315 - recall: 0.4617 - accuracy: 0.8148 - val_loss: 0.1825 - val_iou: 0.8175 - val_dice_coef: 0.6621 - val_precision: 0.6063 - val_recall: 0.9700 - val_accuracy: 0.7914
# Epoch 83/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1987 - iou: 0.8013 - dice_coef: 0.6111 - precision: 0.9312 - recall: 0.4642 - accuracy: 0.8156 - val_loss: 0.0827 - val_iou: 0.9173 - val_dice_coef: 0.7594 - val_precision: 0.8813 - val_recall: 0.8638 - val_accuracy: 0.9208
# Epoch 84/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1967 - iou: 0.8033 - dice_coef: 0.6145 - precision: 0.9445 - recall: 0.4651 - accuracy: 0.8181 - val_loss: 0.0601 - val_iou: 0.9399 - val_dice_coef: 0.7971 - val_precision: 0.9062 - val_recall: 0.9429 - val_accuracy: 0.9506
# Epoch 85/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1976 - iou: 0.8024 - dice_coef: 0.6156 - precision: 0.9357 - recall: 0.4660 - accuracy: 0.8169 - val_loss: 0.0724 - val_iou: 0.9276 - val_dice_coef: 0.7529 - val_precision: 0.9214 - val_recall: 0.9251 - val_accuracy: 0.9512
# Epoch 86/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1951 - iou: 0.8049 - dice_coef: 0.6195 - precision: 0.9473 - recall: 0.4683 - accuracy: 0.8196 - val_loss: 0.1040 - val_iou: 0.8960 - val_dice_coef: 0.7167 - val_precision: 0.8443 - val_recall: 0.9071 - val_accuracy: 0.9177
# Epoch 87/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1967 - iou: 0.8033 - dice_coef: 0.6138 - precision: 0.9435 - recall: 0.4645 - accuracy: 0.8178 - val_loss: 0.0623 - val_iou: 0.9377 - val_dice_coef: 0.7952 - val_precision: 0.8863 - val_recall: 0.9677 - val_accuracy: 0.9502
# Epoch 88/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1966 - iou: 0.8034 - dice_coef: 0.6152 - precision: 0.9356 - recall: 0.4681 - accuracy: 0.8179 - val_loss: 0.1114 - val_iou: 0.8886 - val_dice_coef: 0.7157 - val_precision: 0.7862 - val_recall: 0.9193 - val_accuracy: 0.8944
# Epoch 89/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1971 - iou: 0.8029 - dice_coef: 0.6143 - precision: 0.9449 - recall: 0.4623 - accuracy: 0.8173 - val_loss: 0.1471 - val_iou: 0.8529 - val_dice_coef: 0.6981 - val_precision: 0.6872 - val_recall: 0.9663 - val_accuracy: 0.8496
# Epoch 90/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1994 - iou: 0.8006 - dice_coef: 0.6108 - precision: 0.9249 - recall: 0.4634 - accuracy: 0.8142 - val_loss: 0.2067 - val_iou: 0.7933 - val_dice_coef: 0.6393 - val_precision: 0.5844 - val_recall: 0.8883 - val_accuracy: 0.7662
# Epoch 91/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1986 - iou: 0.8014 - dice_coef: 0.6131 - precision: 0.9402 - recall: 0.4594 - accuracy: 0.8155 - val_loss: 0.1009 - val_iou: 0.8991 - val_dice_coef: 0.7757 - val_precision: 0.7705 - val_recall: 0.9505 - val_accuracy: 0.8966
# Epoch 92/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1969 - iou: 0.8031 - dice_coef: 0.6146 - precision: 0.9429 - recall: 0.4654 - accuracy: 0.8177 - val_loss: 0.1102 - val_iou: 0.8898 - val_dice_coef: 0.7531 - val_precision: 0.7481 - val_recall: 0.9597 - val_accuracy: 0.8865
# Epoch 93/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1965 - iou: 0.8035 - dice_coef: 0.6174 - precision: 0.9456 - recall: 0.4642 - accuracy: 0.8182 - val_loss: 0.2170 - val_iou: 0.7830 - val_dice_coef: 0.6142 - val_precision: 0.5401 - val_recall: 0.9411 - val_accuracy: 0.7306
# Epoch 94/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1981 - iou: 0.8019 - dice_coef: 0.6133 - precision: 0.9309 - recall: 0.4662 - accuracy: 0.8162 - val_loss: 0.0825 - val_iou: 0.9175 - val_dice_coef: 0.7750 - val_precision: 0.8379 - val_recall: 0.9490 - val_accuracy: 0.9265
# Epoch 95/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1964 - iou: 0.8036 - dice_coef: 0.6157 - precision: 0.9408 - recall: 0.4665 - accuracy: 0.8183 - val_loss: 0.1381 - val_iou: 0.8619 - val_dice_coef: 0.7113 - val_precision: 0.6923 - val_recall: 0.9595 - val_accuracy: 0.8546
# Epoch 96/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1950 - iou: 0.8050 - dice_coef: 0.6200 - precision: 0.9498 - recall: 0.4683 - accuracy: 0.8200 - val_loss: 0.0509 - val_iou: 0.9491 - val_dice_coef: 0.8080 - val_precision: 0.9303 - val_recall: 0.9311 - val_accuracy: 0.9555
# Epoch 97/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1949 - iou: 0.8051 - dice_coef: 0.6205 - precision: 0.9471 - recall: 0.4699 - accuracy: 0.8200 - val_loss: 0.1363 - val_iou: 0.8637 - val_dice_coef: 0.6994 - val_precision: 0.6893 - val_recall: 0.9687 - val_accuracy: 0.8528
# Epoch 98/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1976 - iou: 0.8024 - dice_coef: 0.6120 - precision: 0.9346 - recall: 0.4665 - accuracy: 0.8169 - val_loss: 0.0910 - val_iou: 0.9090 - val_dice_coef: 0.7284 - val_precision: 0.8853 - val_recall: 0.8785 - val_accuracy: 0.9267
# Epoch 99/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1965 - iou: 0.8035 - dice_coef: 0.6171 - precision: 0.9432 - recall: 0.4648 - accuracy: 0.8180 - val_loss: 0.0615 - val_iou: 0.9385 - val_dice_coef: 0.7966 - val_precision: 0.8944 - val_recall: 0.9469 - val_accuracy: 0.9472
# Epoch 100/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1947 - iou: 0.8053 - dice_coef: 0.6180 - precision: 0.9450 - recall: 0.4710 - accuracy: 0.8203 - val_loss: 0.0947 - val_iou: 0.9053 - val_dice_coef: 0.7085 - val_precision: 0.9428 - val_recall: 0.8031 - val_accuracy: 0.9208

# %%
model_1 = Model(inputs=img_input, outputs=pred)
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance], metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_1.load_weights('fcn_100_epoch.h5')

# %% [markdown]
# Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 8ms/step
# ________________________
# IOU:       |   90.90  |
# Dice Coef: |   70.84  |
# Precision: |   95.65  |
# Recall:    |   79.60  |
# Accuracy:  |   92.30  |
# Loss:      |   9.10  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 0s 7ms/step
# ________________________
# IOU:       |   91.19  |
# Dice Coef: |   71.34  |
# Precision: |   95.77  |
# Recall:    |   81.18  |
# Accuracy:  |   93.10  |
# Loss:      |   8.81  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   90.53  |
# Dice Coef: |   70.85  |
# Precision: |   94.28  |
# Recall:    |   80.31  |
# Accuracy:  |   92.08  |
# Loss:      |   9.47  |
# ________________________

# %% [markdown]
# ### Plotting Training Statistics

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# From the above plot we can see that for the training set the the loss and the accuracy has gradually decreased and increased respetively.
# Although for the validation set the loss and the accuracy fluctuates but the loss and the accuracy are relatively low and high respectively throughout the training.
# Also the fluctuations relatively lowers towards the end of the training.

# %% [markdown]
# ## Visualising Predicted Lesions

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,192,256,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.

# %% [markdown]
# ### **de nada!**
