# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('../input/*/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('../input/*/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# #### Jaccard Distance
# The Jaccard distance, which measures dissimilarity between sample sets, is complementary to the Jaccard coefficient and is obtained by subtracting the Jaccard coefficient from 1, or, equivalently, by dividing the difference of the sizes of the union and the intersection of two sets by the size of the union:

# %% [markdown]
# ![jd](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-44046533fcd54e98cb53619b3390e083_l3.svg)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coe(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 7
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt adam optimization algorithm or adaptive moments, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * Advantages of Adam optimizer are:
#     - Relatively low memory requirements (though higher than gradient descent and gradient descent with momentum).
#     - Usually works well even with a little tuning of hyperparameter
# * Adam is fairly robust to the choice of hyperparameters, and set the learning rate **α** as 0.003 to speed up the training procedure in this study as advised in the paper [here](https://arxiv.org/pdf/1703.05165v2.pdf)

# %% [markdown]
# ### Model Function

# %% [markdown]
# > ![arch](https://raw.githubusercontent.com/hashbanger/Skin_Lesion_Segmentation/master/graphics/unet_arch.png)

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename):
    dropout_val=0.50
    if K.image_dim_ordering() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224,224))(conv_final)
    model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
    model.save(savename)
    return model, hist

# %% [markdown]
# <font color='red'>**Problems In Guided Dropout Implementation**
#
# - The entire network architecture is implemented using Keras.
# - Now to implement the Guided Dropout Layer using Keras we have to know the detailed backend of the Keras Library because:
# - We should know in what form the inputs will be coming to our layer so we could manipulate them.
# - We should also know in what form the output should be given to the next layer.
# - If we implement Guided Dropout from scratch then we will have to implement entire architecture from scratch which will be neither efficient nor easily feasible.</font>

# %% [markdown]
# ### For 1 epoch

# %%
model, hist = UNET_224(1, 'unet_1_epoch.h5')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 32) 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 224, 224, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 32) 0           spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 64) 36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 112, 112, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 112, 112, 64) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)   0           spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 56, 56, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 128)  0           spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 28, 28, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 256)  0           spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 512)  2359808     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_5 (SpatialDro (None, 14, 14, 512)  0           activation_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 512)    0           spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 1024)   4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 1024)   4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_6 (SpatialDro (None, 7, 7, 1024)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 14, 14, 1024) 0           spatial_dropout2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 1536) 0           up_sampling2d_1[0][0]
#                                                                  spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 512)  2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 14, 14, 512)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_7 (SpatialDro (None, 14, 14, 512)  0           activation_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 28, 28, 512)  0           spatial_dropout2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 768)  0           up_sampling2d_2[0][0]
#                                                                  spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 256)  590080      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_8 (SpatialDro (None, 28, 28, 256)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 56, 56, 256)  0           spatial_dropout2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 384)  0           up_sampling2d_3[0][0]
#                                                                  spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 56, 56, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 56, 56, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 56, 56, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_9 (SpatialDro (None, 56, 56, 128)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 112, 112, 128 0           spatial_dropout2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 112, 112, 192 0           up_sampling2d_4[0][0]
#                                                                  spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 112, 112, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 112, 112, 64) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 112, 112, 64) 36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 112, 112, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 112, 112, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10 (SpatialDr (None, 112, 112, 64) 0           activation_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 224, 224, 64) 0           spatial_dropout2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 224, 224, 96) 0           up_sampling2d_5[0][0]
#                                                                  spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 224, 224, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 224, 224, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 224, 224, 32) 9248        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 224, 224, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 224, 224, 32) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_11 (SpatialDr (None, 224, 224, 32) 0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 224, 224, 1)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 224, 224)     0           activation_23[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/1
# 360/360 [==============================] - 15s 41ms/step - loss: 0.1743 - iou: 0.8257 - dice_coe: 0.5960 - precision: 0.7124 - recall: 0.6588 - accuracy: 0.7938 - val_loss: 0.4747 - val_iou: 0.5253 - val_dice_coe: 0.4752 - val_precision: 0.3132 - val_recall: 1.0000 - val_accuracy: 0.3135

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
dropout_val=0.50
if K.image_dim_ordering() == 'th':
    inputs = Input((INPUT_CHANNELS, 224, 224))
    axis = 1
else:
    inputs = Input((224, 224, INPUT_CHANNELS))
    axis = 3
filters = 32

conv_224 = double_conv_layer(inputs, filters)
pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

conv_112 = double_conv_layer(pool_112, 2*filters)
pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

conv_56 = double_conv_layer(pool_56, 4*filters)
pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

conv_28 = double_conv_layer(pool_28, 8*filters)
pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

conv_14 = double_conv_layer(pool_14, 16*filters)
pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

conv_7 = double_conv_layer(pool_7, 32*filters)

up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
up_conv_14 = double_conv_layer(up_14, 16*filters)

up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
up_conv_28 = double_conv_layer(up_28, 8*filters)

up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
up_conv_56 = double_conv_layer(up_56, 4*filters)

up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
up_conv_112 = double_conv_layer(up_112, 2*filters)

up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
conv_final = Activation('sigmoid')(conv_final)
pred = Reshape((224,224))(conv_final)

# %%
model_0 = Model(inputs, pred, name="UNET_224")
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_0.load_weights('unet_1_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 7ms/step
# ________________________
# IOU:       |   53.26  |
# Dice Coef: |   48.52  |
# Precision: |   32.38  |
# Recall:    |   100.00  |
# Accuracy:  |   32.40  |
# Loss:      |   46.74  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 14ms/step
# ________________________
# IOU:       |   52.56  |
# Dice Coef: |   47.54  |
# Precision: |   31.36  |
# Recall:    |   100.00  |
# Accuracy:  |   31.39  |
# Loss:      |   47.44  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 0s 5ms/step
# ________________________
# IOU:       |   52.53  |
# Dice Coef: |   47.52  |
# Precision: |   31.32  |
# Recall:    |   100.00  |
# Accuracy:  |   31.35  |
# Loss:      |   47.47  |
# ________________________

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = UNET_224(epochs_num= 100, savename= 'unet_100_epoch.h5')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 224, 224, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 224, 224, 32) 128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 224, 224, 32) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 224, 224, 32) 9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 224, 224, 32) 128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 224, 224, 32) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_23 (SpatialDr (None, 224, 224, 32) 0           activation_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 112, 112, 32) 0           spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 112, 112, 64) 18496       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 112, 112, 64) 256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 112, 112, 64) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 112, 112, 64) 36928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 112, 112, 64) 256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 112, 112, 64) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_24 (SpatialDr (None, 112, 112, 64) 0           activation_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 56, 56, 64)   0           spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 56, 56, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 56, 56, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 128)  147584      activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 56, 56, 128)  512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 56, 56, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_25 (SpatialDr (None, 56, 56, 128)  0           activation_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 28, 28, 128)  0           spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 28, 28, 256)  295168      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 28, 28, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 28, 28, 256)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 28, 28, 256)  590080      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 28, 28, 256)  1024        conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 28, 28, 256)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_26 (SpatialDr (None, 28, 28, 256)  0           activation_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 14, 14, 256)  0           spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 512)  1180160     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 512)  2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 512)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 512)  2359808     activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 14, 14, 512)  2048        conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 14, 14, 512)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_27 (SpatialDr (None, 14, 14, 512)  0           activation_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 7, 7, 512)    0           spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 7, 7, 1024)   4096        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 7, 7, 1024)   4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_28 (SpatialDr (None, 7, 7, 1024)   0           activation_58[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 14, 14, 1024) 0           spatial_dropout2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 14, 14, 1536) 0           up_sampling2d_11[0][0]
#                                                                  spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 14, 14, 512)  2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 14, 14, 512)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 14, 14, 512)  2359808     activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 14, 14, 512)  2048        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 14, 14, 512)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_29 (SpatialDr (None, 14, 14, 512)  0           activation_60[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 28, 28, 512)  0           spatial_dropout2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 768)  0           up_sampling2d_12[0][0]
#                                                                  spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 28, 28, 256)  1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 28, 28, 256)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 28, 28, 256)  590080      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 28, 28, 256)  1024        conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 28, 28, 256)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_30 (SpatialDr (None, 28, 28, 256)  0           activation_62[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 56, 56, 256)  0           spatial_dropout2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 56, 56, 384)  0           up_sampling2d_13[0][0]
#                                                                  spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 56, 56, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 56, 56, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 56, 56, 128)  147584      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 56, 56, 128)  512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 56, 56, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_31 (SpatialDr (None, 56, 56, 128)  0           activation_64[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_14[0][0]
#                                                                  spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 112, 112, 64) 256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 112, 112, 64) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 112, 112, 64) 36928       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 112, 112, 64) 256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 112, 112, 64) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_32 (SpatialDr (None, 112, 112, 64) 0           activation_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_15[0][0]
#                                                                  spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 224, 224, 32) 128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 224, 224, 32) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 224, 224, 32) 9248        activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 224, 224, 32) 128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 224, 224, 32) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_33 (SpatialDr (None, 224, 224, 32) 0           activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_33[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 224, 224, 1)  0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 224, 224)     0           activation_69[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 14s 38ms/step - loss: 0.1615 - iou: 0.8385 - dice_coe: 0.6228 - precision: 0.7393 - recall: 0.7031 - accuracy: 0.8167 - val_loss: 0.4611 - val_iou: 0.5389 - val_dice_coe: 0.4877 - val_precision: 0.3244 - val_recall: 1.0000 - val_accuracy: 0.3484
# Epoch 2/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0993 - iou: 0.9007 - dice_coe: 0.7431 - precision: 0.8444 - recall: 0.8091 - accuracy: 0.8879 - val_loss: 0.4498 - val_iou: 0.5502 - val_dice_coe: 0.4940 - val_precision: 0.3290 - val_recall: 0.9998 - val_accuracy: 0.3628
# Epoch 3/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0878 - iou: 0.9122 - dice_coe: 0.7757 - precision: 0.8862 - recall: 0.8120 - accuracy: 0.9038 - val_loss: 0.3550 - val_iou: 0.6450 - val_dice_coe: 0.5706 - val_precision: 0.4018 - val_recall: 0.9949 - val_accuracy: 0.5356
# Epoch 4/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0864 - iou: 0.9136 - dice_coe: 0.7848 - precision: 0.8787 - recall: 0.8182 - accuracy: 0.9015 - val_loss: 0.2671 - val_iou: 0.7329 - val_dice_coe: 0.6317 - val_precision: 0.4962 - val_recall: 0.9156 - val_accuracy: 0.6797
# Epoch 5/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0886 - iou: 0.9114 - dice_coe: 0.7805 - precision: 0.8816 - recall: 0.8033 - accuracy: 0.8993 - val_loss: 0.2479 - val_iou: 0.7521 - val_dice_coe: 0.6511 - val_precision: 0.5170 - val_recall: 0.9261 - val_accuracy: 0.7023
# Epoch 6/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0794 - iou: 0.9206 - dice_coe: 0.8030 - precision: 0.8786 - recall: 0.8452 - accuracy: 0.9103 - val_loss: 0.4678 - val_iou: 0.5322 - val_dice_coe: 0.4811 - val_precision: 0.3173 - val_recall: 1.0000 - val_accuracy: 0.3266
# Epoch 7/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0814 - iou: 0.9186 - dice_coe: 0.7999 - precision: 0.8974 - recall: 0.8143 - accuracy: 0.9065 - val_loss: 0.1168 - val_iou: 0.8832 - val_dice_coe: 0.7932 - val_precision: 0.7399 - val_recall: 0.8786 - val_accuracy: 0.8651
# Epoch 8/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0818 - iou: 0.9182 - dice_coe: 0.8066 - precision: 0.8682 - recall: 0.8392 - accuracy: 0.9054 - val_loss: 0.1303 - val_iou: 0.8697 - val_dice_coe: 0.7810 - val_precision: 0.7117 - val_recall: 0.8803 - val_accuracy: 0.8495
# Epoch 9/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0791 - iou: 0.9209 - dice_coe: 0.8093 - precision: 0.8777 - recall: 0.8366 - accuracy: 0.9071 - val_loss: 0.0970 - val_iou: 0.9030 - val_dice_coe: 0.8340 - val_precision: 0.7671 - val_recall: 0.9286 - val_accuracy: 0.8896
# Epoch 10/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0794 - iou: 0.9206 - dice_coe: 0.8070 - precision: 0.8870 - recall: 0.8240 - accuracy: 0.9054 - val_loss: 0.0761 - val_iou: 0.9239 - val_dice_coe: 0.8587 - val_precision: 0.8362 - val_recall: 0.8930 - val_accuracy: 0.9119
# Epoch 11/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0826 - iou: 0.9174 - dice_coe: 0.8024 - precision: 0.8913 - recall: 0.8199 - accuracy: 0.9046 - val_loss: 0.2090 - val_iou: 0.7910 - val_dice_coe: 0.7118 - val_precision: 0.5611 - val_recall: 0.9773 - val_accuracy: 0.7540
# Epoch 12/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0753 - iou: 0.9247 - dice_coe: 0.8220 - precision: 0.8981 - recall: 0.8279 - accuracy: 0.9118 - val_loss: 0.2304 - val_iou: 0.7696 - val_dice_coe: 0.6800 - val_precision: 0.5230 - val_recall: 0.9794 - val_accuracy: 0.7157
# Epoch 13/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0736 - iou: 0.9264 - dice_coe: 0.8238 - precision: 0.9010 - recall: 0.8350 - accuracy: 0.9144 - val_loss: 0.0722 - val_iou: 0.9278 - val_dice_coe: 0.8437 - val_precision: 0.9348 - val_recall: 0.8004 - val_accuracy: 0.9183
# Epoch 14/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0666 - iou: 0.9334 - dice_coe: 0.8370 - precision: 0.9025 - recall: 0.8651 - accuracy: 0.9238 - val_loss: 0.0888 - val_iou: 0.9112 - val_dice_coe: 0.8138 - val_precision: 0.9774 - val_recall: 0.7215 - val_accuracy: 0.9059
# Epoch 15/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0671 - iou: 0.9329 - dice_coe: 0.8411 - precision: 0.8951 - recall: 0.8721 - accuracy: 0.9217 - val_loss: 0.0654 - val_iou: 0.9346 - val_dice_coe: 0.8655 - val_precision: 0.9596 - val_recall: 0.8037 - val_accuracy: 0.9265
# Epoch 16/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0641 - iou: 0.9359 - dice_coe: 0.8445 - precision: 0.9225 - recall: 0.8481 - accuracy: 0.9263 - val_loss: 0.0664 - val_iou: 0.9336 - val_dice_coe: 0.8651 - val_precision: 0.9522 - val_recall: 0.8070 - val_accuracy: 0.9256
# Epoch 17/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0663 - iou: 0.9337 - dice_coe: 0.8447 - precision: 0.8954 - recall: 0.8762 - accuracy: 0.9251 - val_loss: 0.0986 - val_iou: 0.9014 - val_dice_coe: 0.8339 - val_precision: 0.7727 - val_recall: 0.9254 - val_accuracy: 0.8886
# Epoch 18/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0630 - iou: 0.9370 - dice_coe: 0.8455 - precision: 0.9239 - recall: 0.8518 - accuracy: 0.9280 - val_loss: 0.0581 - val_iou: 0.9419 - val_dice_coe: 0.8893 - val_precision: 0.8915 - val_recall: 0.9054 - val_accuracy: 0.9361
# Epoch 19/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0621 - iou: 0.9379 - dice_coe: 0.8559 - precision: 0.9208 - recall: 0.8658 - accuracy: 0.9309 - val_loss: 0.2537 - val_iou: 0.7463 - val_dice_coe: 0.6447 - val_precision: 0.4966 - val_recall: 0.9383 - val_accuracy: 0.6818
# Epoch 20/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0689 - iou: 0.9311 - dice_coe: 0.8436 - precision: 0.8966 - recall: 0.8603 - accuracy: 0.9209 - val_loss: 0.0843 - val_iou: 0.9157 - val_dice_coe: 0.8474 - val_precision: 0.8673 - val_recall: 0.8382 - val_accuracy: 0.9096
# Epoch 21/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0693 - iou: 0.9307 - dice_coe: 0.8332 - precision: 0.9113 - recall: 0.8416 - accuracy: 0.9200 - val_loss: 0.1102 - val_iou: 0.8898 - val_dice_coe: 0.7671 - val_precision: 0.8614 - val_recall: 0.7239 - val_accuracy: 0.8739
# Epoch 22/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0695 - iou: 0.9305 - dice_coe: 0.8365 - precision: 0.9135 - recall: 0.8345 - accuracy: 0.9193 - val_loss: 0.1104 - val_iou: 0.8896 - val_dice_coe: 0.8158 - val_precision: 0.7285 - val_recall: 0.9545 - val_accuracy: 0.8752
# Epoch 23/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0593 - iou: 0.9407 - dice_coe: 0.8536 - precision: 0.9203 - recall: 0.8745 - accuracy: 0.9323 - val_loss: 0.1306 - val_iou: 0.8694 - val_dice_coe: 0.7691 - val_precision: 0.6913 - val_recall: 0.9749 - val_accuracy: 0.8575
# Epoch 24/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0561 - iou: 0.9439 - dice_coe: 0.8650 - precision: 0.9247 - recall: 0.8796 - accuracy: 0.9365 - val_loss: 0.0582 - val_iou: 0.9418 - val_dice_coe: 0.8818 - val_precision: 0.8800 - val_recall: 0.9173 - val_accuracy: 0.9354
# Epoch 25/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0538 - iou: 0.9462 - dice_coe: 0.8685 - precision: 0.9359 - recall: 0.8733 - accuracy: 0.9383 - val_loss: 0.0927 - val_iou: 0.9073 - val_dice_coe: 0.8361 - val_precision: 0.7604 - val_recall: 0.9641 - val_accuracy: 0.8948
# Epoch 26/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0525 - iou: 0.9475 - dice_coe: 0.8722 - precision: 0.9280 - recall: 0.8918 - accuracy: 0.9413 - val_loss: 0.1029 - val_iou: 0.8971 - val_dice_coe: 0.7996 - val_precision: 0.8075 - val_recall: 0.8422 - val_accuracy: 0.8844
# Epoch 27/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0603 - iou: 0.9397 - dice_coe: 0.8616 - precision: 0.9109 - recall: 0.8755 - accuracy: 0.9307 - val_loss: 0.0825 - val_iou: 0.9175 - val_dice_coe: 0.8329 - val_precision: 0.8464 - val_recall: 0.8835 - val_accuracy: 0.9117
# Epoch 28/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0597 - iou: 0.9403 - dice_coe: 0.8562 - precision: 0.9284 - recall: 0.8641 - accuracy: 0.9328 - val_loss: 0.0816 - val_iou: 0.9184 - val_dice_coe: 0.8335 - val_precision: 0.8676 - val_recall: 0.8393 - val_accuracy: 0.9074
# Epoch 29/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0601 - iou: 0.9399 - dice_coe: 0.8626 - precision: 0.9211 - recall: 0.8677 - accuracy: 0.9310 - val_loss: 0.0503 - val_iou: 0.9497 - val_dice_coe: 0.8926 - val_precision: 0.9391 - val_recall: 0.8785 - val_accuracy: 0.9420
# Epoch 30/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0535 - iou: 0.9465 - dice_coe: 0.8702 - precision: 0.9290 - recall: 0.8840 - accuracy: 0.9392 - val_loss: 0.0491 - val_iou: 0.9509 - val_dice_coe: 0.8980 - val_precision: 0.9131 - val_recall: 0.9102 - val_accuracy: 0.9440
# Epoch 31/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0529 - iou: 0.9471 - dice_coe: 0.8738 - precision: 0.9272 - recall: 0.8878 - accuracy: 0.9403 - val_loss: 0.0787 - val_iou: 0.9213 - val_dice_coe: 0.8524 - val_precision: 0.8987 - val_recall: 0.8299 - val_accuracy: 0.9156
# Epoch 32/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0508 - iou: 0.9492 - dice_coe: 0.8799 - precision: 0.9304 - recall: 0.8962 - accuracy: 0.9431 - val_loss: 0.0952 - val_iou: 0.9048 - val_dice_coe: 0.8044 - val_precision: 0.9603 - val_recall: 0.7158 - val_accuracy: 0.9002
# Epoch 33/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0533 - iou: 0.9467 - dice_coe: 0.8748 - precision: 0.9259 - recall: 0.8903 - accuracy: 0.9399 - val_loss: 0.0460 - val_iou: 0.9540 - val_dice_coe: 0.9020 - val_precision: 0.9134 - val_recall: 0.9261 - val_accuracy: 0.9485
# Epoch 34/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0580 - iou: 0.9420 - dice_coe: 0.8669 - precision: 0.9029 - recall: 0.8929 - accuracy: 0.9325 - val_loss: 0.0535 - val_iou: 0.9465 - val_dice_coe: 0.8904 - val_precision: 0.9014 - val_recall: 0.9138 - val_accuracy: 0.9412
# Epoch 35/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0575 - iou: 0.9425 - dice_coe: 0.8613 - precision: 0.9239 - recall: 0.8769 - accuracy: 0.9332 - val_loss: 0.0916 - val_iou: 0.9084 - val_dice_coe: 0.8289 - val_precision: 0.7881 - val_recall: 0.9163 - val_accuracy: 0.8961
# Epoch 36/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0523 - iou: 0.9477 - dice_coe: 0.8765 - precision: 0.9230 - recall: 0.8918 - accuracy: 0.9390 - val_loss: 0.0572 - val_iou: 0.9428 - val_dice_coe: 0.8762 - val_precision: 0.9358 - val_recall: 0.8419 - val_accuracy: 0.9314
# Epoch 37/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0507 - iou: 0.9493 - dice_coe: 0.8780 - precision: 0.9314 - recall: 0.8882 - accuracy: 0.9416 - val_loss: 0.0710 - val_iou: 0.9290 - val_dice_coe: 0.8495 - val_precision: 0.8396 - val_recall: 0.9259 - val_accuracy: 0.9194
# Epoch 38/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0484 - iou: 0.9516 - dice_coe: 0.8842 - precision: 0.9324 - recall: 0.9035 - accuracy: 0.9466 - val_loss: 0.0530 - val_iou: 0.9470 - val_dice_coe: 0.8873 - val_precision: 0.8999 - val_recall: 0.9052 - val_accuracy: 0.9385
# Epoch 39/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0530 - iou: 0.9470 - dice_coe: 0.8755 - precision: 0.9279 - recall: 0.8875 - accuracy: 0.9389 - val_loss: 0.0467 - val_iou: 0.9533 - val_dice_coe: 0.8922 - val_precision: 0.9698 - val_recall: 0.8496 - val_accuracy: 0.9438
# Epoch 40/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0517 - iou: 0.9483 - dice_coe: 0.8767 - precision: 0.9297 - recall: 0.8885 - accuracy: 0.9414 - val_loss: 0.0596 - val_iou: 0.9404 - val_dice_coe: 0.8743 - val_precision: 0.8525 - val_recall: 0.9389 - val_accuracy: 0.9297
# Epoch 41/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0521 - iou: 0.9479 - dice_coe: 0.8775 - precision: 0.9239 - recall: 0.8889 - accuracy: 0.9401 - val_loss: 0.0473 - val_iou: 0.9527 - val_dice_coe: 0.8943 - val_precision: 0.9292 - val_recall: 0.8998 - val_accuracy: 0.9455
# Epoch 42/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0536 - iou: 0.9464 - dice_coe: 0.8704 - precision: 0.9355 - recall: 0.8788 - accuracy: 0.9391 - val_loss: 0.0854 - val_iou: 0.9146 - val_dice_coe: 0.8407 - val_precision: 0.8000 - val_recall: 0.8961 - val_accuracy: 0.8972
# Epoch 43/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0580 - iou: 0.9420 - dice_coe: 0.8680 - precision: 0.9189 - recall: 0.8763 - accuracy: 0.9328 - val_loss: 0.0621 - val_iou: 0.9379 - val_dice_coe: 0.8814 - val_precision: 0.8848 - val_recall: 0.9098 - val_accuracy: 0.9326
# Epoch 44/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0563 - iou: 0.9437 - dice_coe: 0.8695 - precision: 0.9371 - recall: 0.8688 - accuracy: 0.9358 - val_loss: 0.0386 - val_iou: 0.9614 - val_dice_coe: 0.9155 - val_precision: 0.9608 - val_recall: 0.8944 - val_accuracy: 0.9542
# Epoch 45/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0543 - iou: 0.9457 - dice_coe: 0.8732 - precision: 0.9238 - recall: 0.8878 - accuracy: 0.9382 - val_loss: 0.0452 - val_iou: 0.9548 - val_dice_coe: 0.9039 - val_precision: 0.8949 - val_recall: 0.9471 - val_accuracy: 0.9486
# Epoch 46/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0532 - iou: 0.9468 - dice_coe: 0.8769 - precision: 0.9207 - recall: 0.8954 - accuracy: 0.9393 - val_loss: 0.0425 - val_iou: 0.9575 - val_dice_coe: 0.9073 - val_precision: 0.9392 - val_recall: 0.8975 - val_accuracy: 0.9486
# Epoch 47/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0497 - iou: 0.9503 - dice_coe: 0.8819 - precision: 0.9319 - recall: 0.8928 - accuracy: 0.9429 - val_loss: 0.0725 - val_iou: 0.9275 - val_dice_coe: 0.8561 - val_precision: 0.8505 - val_recall: 0.9119 - val_accuracy: 0.9208
# Epoch 48/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0444 - iou: 0.9556 - dice_coe: 0.8934 - precision: 0.9399 - recall: 0.9042 - accuracy: 0.9494 - val_loss: 0.0551 - val_iou: 0.9449 - val_dice_coe: 0.8853 - val_precision: 0.8812 - val_recall: 0.9350 - val_accuracy: 0.9386
# Epoch 49/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0493 - iou: 0.9507 - dice_coe: 0.8852 - precision: 0.9258 - recall: 0.9038 - accuracy: 0.9434 - val_loss: 0.0421 - val_iou: 0.9579 - val_dice_coe: 0.9065 - val_precision: 0.8948 - val_recall: 0.9626 - val_accuracy: 0.9526
# Epoch 50/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0461 - iou: 0.9539 - dice_coe: 0.8904 - precision: 0.9381 - recall: 0.9014 - accuracy: 0.9480 - val_loss: 0.0638 - val_iou: 0.9362 - val_dice_coe: 0.8765 - val_precision: 0.8443 - val_recall: 0.9334 - val_accuracy: 0.9259
# Epoch 51/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0488 - iou: 0.9512 - dice_coe: 0.8859 - precision: 0.9318 - recall: 0.8986 - accuracy: 0.9445 - val_loss: 0.0528 - val_iou: 0.9472 - val_dice_coe: 0.8780 - val_precision: 0.9198 - val_recall: 0.8760 - val_accuracy: 0.9367
# Epoch 52/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0521 - iou: 0.9479 - dice_coe: 0.8783 - precision: 0.9355 - recall: 0.8862 - accuracy: 0.9400 - val_loss: 0.0547 - val_iou: 0.9453 - val_dice_coe: 0.8685 - val_precision: 0.8958 - val_recall: 0.9064 - val_accuracy: 0.9371
# Epoch 53/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0473 - iou: 0.9527 - dice_coe: 0.8891 - precision: 0.9297 - recall: 0.9078 - accuracy: 0.9470 - val_loss: 0.0630 - val_iou: 0.9370 - val_dice_coe: 0.8653 - val_precision: 0.8923 - val_recall: 0.8832 - val_accuracy: 0.9281
# Epoch 54/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0451 - iou: 0.9549 - dice_coe: 0.8925 - precision: 0.9374 - recall: 0.9045 - accuracy: 0.9487 - val_loss: 0.0393 - val_iou: 0.9607 - val_dice_coe: 0.9018 - val_precision: 0.9599 - val_recall: 0.8842 - val_accuracy: 0.9506
# Epoch 55/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0462 - iou: 0.9538 - dice_coe: 0.8948 - precision: 0.9409 - recall: 0.8974 - accuracy: 0.9481 - val_loss: 0.0591 - val_iou: 0.9409 - val_dice_coe: 0.8679 - val_precision: 0.9733 - val_recall: 0.7988 - val_accuracy: 0.9290
# Epoch 56/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0452 - iou: 0.9548 - dice_coe: 0.8921 - precision: 0.9304 - recall: 0.9119 - accuracy: 0.9486 - val_loss: 0.0398 - val_iou: 0.9602 - val_dice_coe: 0.9029 - val_precision: 0.9525 - val_recall: 0.8923 - val_accuracy: 0.9512
# Epoch 57/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0437 - iou: 0.9563 - dice_coe: 0.8973 - precision: 0.9384 - recall: 0.9112 - accuracy: 0.9506 - val_loss: 0.0441 - val_iou: 0.9559 - val_dice_coe: 0.8993 - val_precision: 0.9647 - val_recall: 0.8611 - val_accuracy: 0.9459
# Epoch 58/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0418 - iou: 0.9582 - dice_coe: 0.9031 - precision: 0.9367 - recall: 0.9166 - accuracy: 0.9525 - val_loss: 0.0380 - val_iou: 0.9620 - val_dice_coe: 0.9126 - val_precision: 0.9237 - val_recall: 0.9366 - val_accuracy: 0.9552
# Epoch 59/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0509 - iou: 0.9491 - dice_coe: 0.8818 - precision: 0.9437 - recall: 0.8776 - accuracy: 0.9411 - val_loss: 0.0589 - val_iou: 0.9411 - val_dice_coe: 0.8863 - val_precision: 0.8394 - val_recall: 0.9741 - val_accuracy: 0.9334
# Epoch 60/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0472 - iou: 0.9528 - dice_coe: 0.8915 - precision: 0.9398 - recall: 0.8959 - accuracy: 0.9469 - val_loss: 0.0739 - val_iou: 0.9261 - val_dice_coe: 0.8627 - val_precision: 0.7960 - val_recall: 0.9788 - val_accuracy: 0.9144
# Epoch 61/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0461 - iou: 0.9539 - dice_coe: 0.8890 - precision: 0.9346 - recall: 0.9062 - accuracy: 0.9466 - val_loss: 0.0482 - val_iou: 0.9518 - val_dice_coe: 0.8907 - val_precision: 0.8826 - val_recall: 0.9540 - val_accuracy: 0.9447
# Epoch 62/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0458 - iou: 0.9542 - dice_coe: 0.8910 - precision: 0.9275 - recall: 0.9098 - accuracy: 0.9467 - val_loss: 0.0458 - val_iou: 0.9542 - val_dice_coe: 0.8930 - val_precision: 0.9190 - val_recall: 0.9150 - val_accuracy: 0.9461
# Epoch 63/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0447 - iou: 0.9553 - dice_coe: 0.8960 - precision: 0.9390 - recall: 0.9050 - accuracy: 0.9493 - val_loss: 0.0443 - val_iou: 0.9557 - val_dice_coe: 0.8965 - val_precision: 0.9434 - val_recall: 0.8882 - val_accuracy: 0.9462
# Epoch 64/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0432 - iou: 0.9568 - dice_coe: 0.8998 - precision: 0.9373 - recall: 0.9105 - accuracy: 0.9507 - val_loss: 0.0649 - val_iou: 0.9351 - val_dice_coe: 0.8625 - val_precision: 0.9138 - val_recall: 0.8482 - val_accuracy: 0.9242
# Epoch 65/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0455 - iou: 0.9545 - dice_coe: 0.8923 - precision: 0.9378 - recall: 0.8998 - accuracy: 0.9484 - val_loss: 0.0552 - val_iou: 0.9448 - val_dice_coe: 0.8820 - val_precision: 0.9026 - val_recall: 0.8983 - val_accuracy: 0.9360
# Epoch 66/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0487 - iou: 0.9513 - dice_coe: 0.8873 - precision: 0.9296 - recall: 0.9019 - accuracy: 0.9443 - val_loss: 0.0604 - val_iou: 0.9396 - val_dice_coe: 0.8731 - val_precision: 0.9689 - val_recall: 0.8026 - val_accuracy: 0.9292
# Epoch 67/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0466 - iou: 0.9534 - dice_coe: 0.8905 - precision: 0.9355 - recall: 0.8992 - accuracy: 0.9462 - val_loss: 0.0381 - val_iou: 0.9619 - val_dice_coe: 0.9139 - val_precision: 0.9370 - val_recall: 0.9234 - val_accuracy: 0.9549
# Epoch 68/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0463 - iou: 0.9537 - dice_coe: 0.8912 - precision: 0.9312 - recall: 0.9046 - accuracy: 0.9469 - val_loss: 0.0556 - val_iou: 0.9444 - val_dice_coe: 0.8862 - val_precision: 0.8701 - val_recall: 0.9432 - val_accuracy: 0.9380
# Epoch 69/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0476 - iou: 0.9524 - dice_coe: 0.8872 - precision: 0.9470 - recall: 0.8913 - accuracy: 0.9459 - val_loss: 0.0387 - val_iou: 0.9613 - val_dice_coe: 0.9152 - val_precision: 0.9378 - val_recall: 0.9164 - val_accuracy: 0.9546
# Epoch 70/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0435 - iou: 0.9565 - dice_coe: 0.8995 - precision: 0.9358 - recall: 0.9135 - accuracy: 0.9510 - val_loss: 0.0389 - val_iou: 0.9611 - val_dice_coe: 0.9164 - val_precision: 0.9177 - val_recall: 0.9394 - val_accuracy: 0.9544
# Epoch 71/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0469 - iou: 0.9531 - dice_coe: 0.8900 - precision: 0.9264 - recall: 0.9070 - accuracy: 0.9456 - val_loss: 0.0360 - val_iou: 0.9640 - val_dice_coe: 0.9091 - val_precision: 0.9457 - val_recall: 0.9116 - val_accuracy: 0.9549
# Epoch 72/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0428 - iou: 0.9572 - dice_coe: 0.8983 - precision: 0.9374 - recall: 0.9135 - accuracy: 0.9516 - val_loss: 0.0509 - val_iou: 0.9491 - val_dice_coe: 0.8843 - val_precision: 0.8679 - val_recall: 0.9704 - val_accuracy: 0.9448
# Epoch 73/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0484 - iou: 0.9516 - dice_coe: 0.8840 - precision: 0.9217 - recall: 0.9067 - accuracy: 0.9438 - val_loss: 0.0537 - val_iou: 0.9463 - val_dice_coe: 0.8607 - val_precision: 0.8982 - val_recall: 0.9480 - val_accuracy: 0.9491
# Epoch 74/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0441 - iou: 0.9559 - dice_coe: 0.8985 - precision: 0.9502 - recall: 0.8967 - accuracy: 0.9496 - val_loss: 0.0461 - val_iou: 0.9539 - val_dice_coe: 0.8910 - val_precision: 0.8882 - val_recall: 0.9637 - val_accuracy: 0.9502
# Epoch 75/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0401 - iou: 0.9599 - dice_coe: 0.9065 - precision: 0.9339 - recall: 0.9253 - accuracy: 0.9539 - val_loss: 0.0377 - val_iou: 0.9623 - val_dice_coe: 0.9101 - val_precision: 0.9557 - val_recall: 0.8906 - val_accuracy: 0.9521
# Epoch 76/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0386 - iou: 0.9614 - dice_coe: 0.9098 - precision: 0.9439 - recall: 0.9221 - accuracy: 0.9565 - val_loss: 0.0386 - val_iou: 0.9614 - val_dice_coe: 0.9091 - val_precision: 0.9404 - val_recall: 0.9189 - val_accuracy: 0.9548
# Epoch 77/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0398 - iou: 0.9602 - dice_coe: 0.9064 - precision: 0.9396 - recall: 0.9189 - accuracy: 0.9544 - val_loss: 0.0384 - val_iou: 0.9616 - val_dice_coe: 0.9167 - val_precision: 0.9384 - val_recall: 0.9206 - val_accuracy: 0.9551
# Epoch 78/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0463 - iou: 0.9537 - dice_coe: 0.8908 - precision: 0.9260 - recall: 0.9111 - accuracy: 0.9467 - val_loss: 0.0961 - val_iou: 0.9039 - val_dice_coe: 0.8298 - val_precision: 0.7453 - val_recall: 0.9830 - val_accuracy: 0.8899
# Epoch 79/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0475 - iou: 0.9525 - dice_coe: 0.8899 - precision: 0.9311 - recall: 0.9012 - accuracy: 0.9458 - val_loss: 0.0675 - val_iou: 0.9325 - val_dice_coe: 0.8499 - val_precision: 0.9775 - val_recall: 0.7733 - val_accuracy: 0.9209
# Epoch 80/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0422 - iou: 0.9578 - dice_coe: 0.8962 - precision: 0.9457 - recall: 0.9077 - accuracy: 0.9520 - val_loss: 0.0466 - val_iou: 0.9534 - val_dice_coe: 0.8934 - val_precision: 0.9641 - val_recall: 0.8575 - val_accuracy: 0.9433
# Epoch 81/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0400 - iou: 0.9600 - dice_coe: 0.9088 - precision: 0.9414 - recall: 0.9201 - accuracy: 0.9546 - val_loss: 0.0566 - val_iou: 0.9434 - val_dice_coe: 0.8835 - val_precision: 0.8801 - val_recall: 0.9272 - val_accuracy: 0.9351
# Epoch 82/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0396 - iou: 0.9604 - dice_coe: 0.9038 - precision: 0.9376 - recall: 0.9253 - accuracy: 0.9555 - val_loss: 0.0532 - val_iou: 0.9468 - val_dice_coe: 0.8755 - val_precision: 0.8968 - val_recall: 0.9252 - val_accuracy: 0.9416
# Epoch 83/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0417 - iou: 0.9583 - dice_coe: 0.9013 - precision: 0.9411 - recall: 0.9120 - accuracy: 0.9528 - val_loss: 0.0412 - val_iou: 0.9588 - val_dice_coe: 0.8998 - val_precision: 0.9386 - val_recall: 0.9096 - val_accuracy: 0.9514
# Epoch 84/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0398 - iou: 0.9602 - dice_coe: 0.9075 - precision: 0.9419 - recall: 0.9201 - accuracy: 0.9558 - val_loss: 0.0499 - val_iou: 0.9501 - val_dice_coe: 0.8933 - val_precision: 0.9760 - val_recall: 0.8351 - val_accuracy: 0.9404
# Epoch 85/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0429 - iou: 0.9571 - dice_coe: 0.9007 - precision: 0.9440 - recall: 0.9080 - accuracy: 0.9524 - val_loss: 0.0666 - val_iou: 0.9334 - val_dice_coe: 0.8645 - val_precision: 0.9673 - val_recall: 0.7865 - val_accuracy: 0.9231
# Epoch 86/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0417 - iou: 0.9583 - dice_coe: 0.9042 - precision: 0.9461 - recall: 0.9087 - accuracy: 0.9525 - val_loss: 0.0586 - val_iou: 0.9414 - val_dice_coe: 0.8696 - val_precision: 0.9707 - val_recall: 0.8057 - val_accuracy: 0.9302
# Epoch 87/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0429 - iou: 0.9571 - dice_coe: 0.8974 - precision: 0.9427 - recall: 0.9100 - accuracy: 0.9519 - val_loss: 0.0410 - val_iou: 0.9590 - val_dice_coe: 0.9000 - val_precision: 0.9466 - val_recall: 0.8989 - val_accuracy: 0.9507
# Epoch 88/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0460 - iou: 0.9540 - dice_coe: 0.8956 - precision: 0.9258 - recall: 0.9127 - accuracy: 0.9472 - val_loss: 0.0455 - val_iou: 0.9545 - val_dice_coe: 0.9039 - val_precision: 0.9581 - val_recall: 0.8723 - val_accuracy: 0.9467
# Epoch 89/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0429 - iou: 0.9571 - dice_coe: 0.9014 - precision: 0.9365 - recall: 0.9134 - accuracy: 0.9513 - val_loss: 0.0524 - val_iou: 0.9476 - val_dice_coe: 0.8904 - val_precision: 0.9759 - val_recall: 0.8278 - val_accuracy: 0.9381
# Epoch 90/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0383 - iou: 0.9617 - dice_coe: 0.9089 - precision: 0.9399 - recall: 0.9260 - accuracy: 0.9569 - val_loss: 0.0393 - val_iou: 0.9607 - val_dice_coe: 0.9114 - val_precision: 0.9603 - val_recall: 0.8838 - val_accuracy: 0.9512
# Epoch 91/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0412 - iou: 0.9588 - dice_coe: 0.9047 - precision: 0.9452 - recall: 0.9122 - accuracy: 0.9526 - val_loss: 0.0507 - val_iou: 0.9493 - val_dice_coe: 0.8906 - val_precision: 0.9611 - val_recall: 0.8380 - val_accuracy: 0.9381
# Epoch 92/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0402 - iou: 0.9598 - dice_coe: 0.9052 - precision: 0.9348 - recall: 0.9223 - accuracy: 0.9542 - val_loss: 0.0341 - val_iou: 0.9659 - val_dice_coe: 0.9197 - val_precision: 0.9540 - val_recall: 0.9147 - val_accuracy: 0.9585
# Epoch 93/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0445 - iou: 0.9555 - dice_coe: 0.8952 - precision: 0.9296 - recall: 0.9122 - accuracy: 0.9487 - val_loss: 0.1214 - val_iou: 0.8786 - val_dice_coe: 0.7291 - val_precision: 0.9808 - val_recall: 0.5804 - val_accuracy: 0.8654
# Epoch 94/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0423 - iou: 0.9577 - dice_coe: 0.9030 - precision: 0.9416 - recall: 0.9124 - accuracy: 0.9527 - val_loss: 0.0971 - val_iou: 0.9029 - val_dice_coe: 0.7905 - val_precision: 0.8011 - val_recall: 0.8368 - val_accuracy: 0.8793
# Epoch 95/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0409 - iou: 0.9591 - dice_coe: 0.9054 - precision: 0.9458 - recall: 0.9104 - accuracy: 0.9532 - val_loss: 0.0617 - val_iou: 0.9383 - val_dice_coe: 0.8716 - val_precision: 0.8710 - val_recall: 0.8949 - val_accuracy: 0.9254
# Epoch 96/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0402 - iou: 0.9598 - dice_coe: 0.9066 - precision: 0.9428 - recall: 0.9154 - accuracy: 0.9542 - val_loss: 0.1924 - val_iou: 0.8076 - val_dice_coe: 0.7089 - val_precision: 0.5668 - val_recall: 0.9789 - val_accuracy: 0.7604
# Epoch 97/100
# 360/360 [==============================] - 6s 16ms/step - loss: 0.0450 - iou: 0.9550 - dice_coe: 0.8968 - precision: 0.9316 - recall: 0.9144 - accuracy: 0.9499 - val_loss: 0.0625 - val_iou: 0.9375 - val_dice_coe: 0.8783 - val_precision: 0.8309 - val_recall: 0.9603 - val_accuracy: 0.9269
# Epoch 98/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0439 - iou: 0.9561 - dice_coe: 0.8992 - precision: 0.9481 - recall: 0.8970 - accuracy: 0.9495 - val_loss: 0.0471 - val_iou: 0.9529 - val_dice_coe: 0.8979 - val_precision: 0.9165 - val_recall: 0.9038 - val_accuracy: 0.9442
# Epoch 99/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0385 - iou: 0.9615 - dice_coe: 0.9079 - precision: 0.9404 - recall: 0.9293 - accuracy: 0.9571 - val_loss: 0.0392 - val_iou: 0.9608 - val_dice_coe: 0.9144 - val_precision: 0.9128 - val_recall: 0.9490 - val_accuracy: 0.9548
# Epoch 100/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0395 - iou: 0.9605 - dice_coe: 0.9108 - precision: 0.9419 - recall: 0.9206 - accuracy: 0.9555 - val_loss: 0.0519 - val_iou: 0.9481 - val_dice_coe: 0.8919 - val_precision: 0.8624 - val_recall: 0.9681 - val_accuracy: 0.9418

# %%
model_1 = Model(inputs, pred, name="UNET_224")
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_1.load_weights('unet_100_epoch.h5')

# %% [markdown]
# ![](http://)Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 9ms/step
# ________________________
# IOU:       |   94.92  |
# Dice Coef: |   89.58  |
# Precision: |   87.83  |
# Recall:    |   96.30  |
# Accuracy:  |   94.55  |
# Loss:      |   5.08  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 0s 5ms/step
# ________________________
# IOU:       |   93.85  |
# Dice Coef: |   87.95  |
# Precision: |   84.86  |
# Recall:    |   95.95  |
# Accuracy:  |   93.57  |
# Loss:      |   6.15  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 0s 5ms/step
# ________________________
# IOU:       |   94.81  |
# Dice Coef: |   89.19  |
# Precision: |   86.24  |
# Recall:    |   96.81  |
# Accuracy:  |   94.18  |
# Loss:      |   5.19  |
# ________________________

# %% [markdown]
# ### Plotting Training Stats

# %% [markdown]
# ## Visualising Predicted Lesions

# %%
plt.figure(figsize=(20, 14))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(2,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(2,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.subplot(2,2,3)
plt.plot(hist.history['val_loss'], 'red')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Valdiation Loss')
plt.subplot(2,2,4)
plt.plot(hist.history['val_accuracy'], 'green')
plt.yticks(list(np.arange(0.0, 1.0, 0.10)))
plt.title('Validation Accuracy')
plt.show()

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224, 224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,224,224,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.

# %% [markdown]
# ### **de nada!**
