# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, concatenate, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras.layers.core import SpatialDropout2D
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
np.random.seed(101)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('../input/*/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('../input/*/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# #### Jaccard Distance
# The Jaccard distance, which measures dissimilarity between sample sets, is complementary to the Jaccard coefficient and is obtained by subtracting the Jaccard coefficient from 1, or, equivalently, by dividing the difference of the sizes of the union and the intersection of two sets by the size of the union:

# %% [markdown]
# ![jd](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-44046533fcd54e98cb53619b3390e083_l3.svg)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coe(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 7
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt adam optimization algorithm or adaptive moments, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * Advantages of Adam optimizer are:
#     - Relatively low memory requirements (though higher than gradient descent and gradient descent with momentum).
#     - Usually works well even with a little tuning of hyperparameter
# * Adam is fairly robust to the choice of hyperparameters, and set the learning rate **α** as 0.003 to speed up the training procedure in this study as advised in the paper [here](https://arxiv.org/pdf/1703.05165v2.pdf)

# %% [markdown]
# ### Model Function

# %% [markdown]
# > ![arch](https://raw.githubusercontent.com/hashbanger/Skin_Lesion_Segmentation/master/graphics/unet_arch.png)

# %%
# Number of image channels (for example 3 in case of RGB, or 1 for grayscale images)
INPUT_CHANNELS = 3
# Number of output masks (1 in case you predict only one type of objects)
OUTPUT_MASK_CHANNELS = 1
# Pretrained weights

# %%
def double_conv_layer(x, size, dropout=0.40, batch_norm=True):
    if K.image_dim_ordering() == 'th':
        axis = 1
    else:
        axis = 3
    conv = Conv2D(size, (3, 3), padding='same')(x)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    conv = Conv2D(size, (3, 3), padding='same')(conv)
    if batch_norm is True:
        conv = BatchNormalization(axis=axis)(conv)
    conv = Activation('relu')(conv)
    if dropout > 0:
        conv = SpatialDropout2D(dropout)(conv)
    return conv


def UNET_224(epochs_num, savename):
    dropout_val=0.50
    if K.image_dim_ordering() == 'th':
        inputs = Input((INPUT_CHANNELS, 224, 224))
        axis = 1
    else:
        inputs = Input((224, 224, INPUT_CHANNELS))
        axis = 3
    filters = 32

    conv_224 = double_conv_layer(inputs, filters)
    pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

    conv_112 = double_conv_layer(pool_112, 2*filters)
    pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

    conv_56 = double_conv_layer(pool_56, 4*filters)
    pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

    conv_28 = double_conv_layer(pool_28, 8*filters)
    pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

    conv_14 = double_conv_layer(pool_14, 16*filters)
    pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

    conv_7 = double_conv_layer(pool_7, 32*filters)

    up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
    up_conv_14 = double_conv_layer(up_14, 16*filters)

    up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
    up_conv_28 = double_conv_layer(up_28, 8*filters)

    up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
    up_conv_56 = double_conv_layer(up_56, 4*filters)

    up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
    up_conv_112 = double_conv_layer(up_112, 2*filters)

    up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
    up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

    conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
    conv_final = Activation('sigmoid')(conv_final)
    pred = Reshape((224,224))(conv_final)
    model = Model(inputs, pred, name="UNET_224")
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])
    model.summary()
    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18,validation_data=(x_val, y_val), verbose=1)
    model.save(savename)
    return model, hist

# %% [markdown]
# <font color='red'>**Problems In Guided Dropout Implementation**
#
# - The entire network architecture is implemented using Keras.
# - Now to implement the Guided Dropout Layer using Keras we have to know the detailed backend of the Keras Library because:
# - We should know in what form the inputs will be coming to our layer so we could manipulate them.
# - We should also know in what form the output should be given to the next layer.
# - If we implement Guided Dropout from scratch then we will have to implement entire architecture from scratch which will be neither efficient nor easily feasible.</font>

# %% [markdown]
# ### For 1 epoch

# %%
model, hist = UNET_224(1, 'unet_1_epoch.h5')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 224, 224, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 224, 224, 32) 128         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 224, 224, 32) 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 224, 224, 32) 9248        activation_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 224, 224, 32) 128         conv2d_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 224, 224, 32) 0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_1 (SpatialDro (None, 224, 224, 32) 0           activation_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 112, 112, 32) 0           spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 112, 112, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 112, 112, 64) 256         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 112, 112, 64) 0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 112, 112, 64) 36928       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 112, 112, 64) 256         conv2d_4[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 112, 112, 64) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_2 (SpatialDro (None, 112, 112, 64) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 56, 56, 64)   0           spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 56, 56, 128)  73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 56, 56, 128)  512         conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 56, 56, 128)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 56, 56, 128)  147584      activation_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 56, 56, 128)  512         conv2d_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 56, 56, 128)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_3 (SpatialDro (None, 56, 56, 128)  0           activation_6[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 28, 28, 128)  0           spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 28, 28, 256)  1024        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 28, 28, 256)  0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 256)  590080      activation_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 28, 28, 256)  1024        conv2d_8[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 28, 28, 256)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_4 (SpatialDro (None, 28, 28, 256)  0           activation_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 256)  0           spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 14, 14, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 14, 14, 512)  2048        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 14, 14, 512)  0           batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 14, 14, 512)  2359808     activation_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 14, 14, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 14, 14, 512)  0           batch_normalization_10[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_5 (SpatialDro (None, 14, 14, 512)  0           activation_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 7, 7, 512)    0           spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 7, 7, 1024)   4096        conv2d_11[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 7, 7, 1024)   4096        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_12[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_6 (SpatialDro (None, 7, 7, 1024)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 14, 14, 1024) 0           spatial_dropout2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 14, 14, 1536) 0           up_sampling2d_1[0][0]
#                                                                  spatial_dropout2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 14, 14, 512)  2048        conv2d_13[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 14, 14, 512)  0           batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 512)  2359808     activation_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 14, 14, 512)  2048        conv2d_14[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 14, 14, 512)  0           batch_normalization_14[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_7 (SpatialDro (None, 14, 14, 512)  0           activation_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 28, 28, 512)  0           spatial_dropout2d_7[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 28, 28, 768)  0           up_sampling2d_2[0][0]
#                                                                  spatial_dropout2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 28, 28, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 28, 28, 256)  0           batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 28, 28, 256)  590080      activation_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_16 (BatchNo (None, 28, 28, 256)  1024        conv2d_16[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 28, 28, 256)  0           batch_normalization_16[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_8 (SpatialDro (None, 28, 28, 256)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 56, 56, 256)  0           spatial_dropout2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 56, 56, 384)  0           up_sampling2d_3[0][0]
#                                                                  spatial_dropout2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_17 (BatchNo (None, 56, 56, 128)  512         conv2d_17[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 56, 56, 128)  0           batch_normalization_17[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 56, 56, 128)  147584      activation_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_18 (BatchNo (None, 56, 56, 128)  512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 56, 56, 128)  0           batch_normalization_18[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_9 (SpatialDro (None, 56, 56, 128)  0           activation_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 112, 112, 128 0           spatial_dropout2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 112, 112, 192 0           up_sampling2d_4[0][0]
#                                                                  spatial_dropout2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_19 (BatchNo (None, 112, 112, 64) 256         conv2d_19[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 112, 112, 64) 0           batch_normalization_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 112, 112, 64) 36928       activation_19[0][0]
# __________________________________________________________________________________________________
# batch_normalization_20 (BatchNo (None, 112, 112, 64) 256         conv2d_20[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 112, 112, 64) 0           batch_normalization_20[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_10 (SpatialDr (None, 112, 112, 64) 0           activation_20[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 224, 224, 64) 0           spatial_dropout2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 224, 224, 96) 0           up_sampling2d_5[0][0]
#                                                                  spatial_dropout2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_21 (BatchNo (None, 224, 224, 32) 128         conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 224, 224, 32) 0           batch_normalization_21[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 224, 224, 32) 9248        activation_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_22 (BatchNo (None, 224, 224, 32) 128         conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 224, 224, 32) 0           batch_normalization_22[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_11 (SpatialDr (None, 224, 224, 32) 0           activation_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 224, 224, 1)  0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 224, 224)     0           activation_23[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/1
# 360/360 [==============================] - 16s 45ms/step - loss: 0.1737 - iou: 0.8263 - dice_coe: 0.5965 - precision: 0.7169 - recall: 0.6582 - accuracy: 0.7953 - val_loss: 0.4749 - val_iou: 0.5251 - val_dice_coe: 0.4750 - val_precision: 0.3131 - val_recall: 1.0000 - val_accuracy: 0.3131

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
dropout_val=0.50
if K.image_dim_ordering() == 'th':
    inputs = Input((INPUT_CHANNELS, 224, 224))
    axis = 1
else:
    inputs = Input((224, 224, INPUT_CHANNELS))
    axis = 3
filters = 32

conv_224 = double_conv_layer(inputs, filters)
pool_112 = MaxPooling2D(pool_size=(2, 2))(conv_224)

conv_112 = double_conv_layer(pool_112, 2*filters)
pool_56 = MaxPooling2D(pool_size=(2, 2))(conv_112)

conv_56 = double_conv_layer(pool_56, 4*filters)
pool_28 = MaxPooling2D(pool_size=(2, 2))(conv_56)

conv_28 = double_conv_layer(pool_28, 8*filters)
pool_14 = MaxPooling2D(pool_size=(2, 2))(conv_28)

conv_14 = double_conv_layer(pool_14, 16*filters)
pool_7 = MaxPooling2D(pool_size=(2, 2))(conv_14)

conv_7 = double_conv_layer(pool_7, 32*filters)

up_14 = concatenate([UpSampling2D(size=(2, 2))(conv_7), conv_14], axis=axis)
up_conv_14 = double_conv_layer(up_14, 16*filters)

up_28 = concatenate([UpSampling2D(size=(2, 2))(up_conv_14), conv_28], axis=axis)
up_conv_28 = double_conv_layer(up_28, 8*filters)

up_56 = concatenate([UpSampling2D(size=(2, 2))(up_conv_28), conv_56], axis=axis)
up_conv_56 = double_conv_layer(up_56, 4*filters)

up_112 = concatenate([UpSampling2D(size=(2, 2))(up_conv_56), conv_112], axis=axis)
up_conv_112 = double_conv_layer(up_112, 2*filters)

up_224 = concatenate([UpSampling2D(size=(2, 2))(up_conv_112), conv_224], axis=axis)
up_conv_224 = double_conv_layer(up_224, filters, dropout_val)

conv_final = Conv2D(OUTPUT_MASK_CHANNELS, (1, 1))(up_conv_224)
conv_final = Activation('sigmoid')(conv_final)
pred = Reshape((224,224))(conv_final)

# %%
model_0 = Model(inputs, pred, name="UNET_224")
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_0.load_weights('unet_1_epoch.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 7ms/step
# ________________________
# IOU:       |   53.24  |
# Dice Coef: |   48.51  |
# Precision: |   32.37  |
# Recall:    |   100.00  |
# Accuracy:  |   32.37  |
# Loss:      |   46.76  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 14ms/step
# ________________________
# IOU:       |   52.54  |
# Dice Coef: |   47.52  |
# Precision: |   31.35  |
# Recall:    |   100.00  |
# Accuracy:  |   31.36  |
# Loss:      |   47.46  |
# ________________________

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = UNET_224(epochs_num= 100, savename= 'unet_100_epoch.h5')
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 224, 224, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 224, 224, 32) 128         conv2d_47[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 224, 224, 32) 0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 224, 224, 32) 9248        activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 224, 224, 32) 128         conv2d_48[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 224, 224, 32) 0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_23 (SpatialDr (None, 224, 224, 32) 0           activation_48[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D) (None, 112, 112, 32) 0           spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 112, 112, 64) 18496       max_pooling2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 112, 112, 64) 256         conv2d_49[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 112, 112, 64) 0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 112, 112, 64) 36928       activation_49[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 112, 112, 64) 256         conv2d_50[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 112, 112, 64) 0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_24 (SpatialDr (None, 112, 112, 64) 0           activation_50[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D) (None, 56, 56, 64)   0           spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 56, 56, 128)  73856       max_pooling2d_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_49 (BatchNo (None, 56, 56, 128)  512         conv2d_51[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 56, 56, 128)  0           batch_normalization_49[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 56, 56, 128)  147584      activation_51[0][0]
# __________________________________________________________________________________________________
# batch_normalization_50 (BatchNo (None, 56, 56, 128)  512         conv2d_52[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 56, 56, 128)  0           batch_normalization_50[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_25 (SpatialDr (None, 56, 56, 128)  0           activation_52[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D) (None, 28, 28, 128)  0           spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 28, 28, 256)  295168      max_pooling2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_51 (BatchNo (None, 28, 28, 256)  1024        conv2d_53[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 28, 28, 256)  0           batch_normalization_51[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 28, 28, 256)  590080      activation_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_52 (BatchNo (None, 28, 28, 256)  1024        conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 28, 28, 256)  0           batch_normalization_52[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_26 (SpatialDr (None, 28, 28, 256)  0           activation_54[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_14 (MaxPooling2D) (None, 14, 14, 256)  0           spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 14, 14, 512)  1180160     max_pooling2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 14, 14, 512)  2048        conv2d_55[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 14, 14, 512)  0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 14, 14, 512)  2359808     activation_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 14, 14, 512)  2048        conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 14, 14, 512)  0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_27 (SpatialDr (None, 14, 14, 512)  0           activation_56[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 7, 7, 512)    0           spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 7, 7, 1024)   4719616     max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 7, 7, 1024)   4096        conv2d_57[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 7, 7, 1024)   9438208     activation_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 7, 7, 1024)   4096        conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 7, 7, 1024)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_28 (SpatialDr (None, 7, 7, 1024)   0           activation_58[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_11 (UpSampling2D) (None, 14, 14, 1024) 0           spatial_dropout2d_28[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 14, 14, 1536) 0           up_sampling2d_11[0][0]
#                                                                  spatial_dropout2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 14, 14, 512)  7078400     concatenate_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 14, 14, 512)  2048        conv2d_59[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 14, 14, 512)  0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 14, 14, 512)  2359808     activation_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 14, 14, 512)  2048        conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 14, 14, 512)  0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_29 (SpatialDr (None, 14, 14, 512)  0           activation_60[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_12 (UpSampling2D) (None, 28, 28, 512)  0           spatial_dropout2d_29[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 28, 28, 768)  0           up_sampling2d_12[0][0]
#                                                                  spatial_dropout2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 28, 28, 256)  1769728     concatenate_12[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 28, 28, 256)  1024        conv2d_61[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 28, 28, 256)  0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 28, 28, 256)  590080      activation_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 28, 28, 256)  1024        conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 28, 28, 256)  0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_30 (SpatialDr (None, 28, 28, 256)  0           activation_62[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_13 (UpSampling2D) (None, 56, 56, 256)  0           spatial_dropout2d_30[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 56, 56, 384)  0           up_sampling2d_13[0][0]
#                                                                  spatial_dropout2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 56, 56, 128)  442496      concatenate_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 56, 56, 128)  512         conv2d_63[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 56, 56, 128)  0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 56, 56, 128)  147584      activation_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 56, 56, 128)  512         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 56, 56, 128)  0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_31 (SpatialDr (None, 56, 56, 128)  0           activation_64[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_14 (UpSampling2D) (None, 112, 112, 128 0           spatial_dropout2d_31[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 112, 112, 192 0           up_sampling2d_14[0][0]
#                                                                  spatial_dropout2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 112, 112, 64) 110656      concatenate_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 112, 112, 64) 256         conv2d_65[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 112, 112, 64) 0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 112, 112, 64) 36928       activation_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 112, 112, 64) 256         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 112, 112, 64) 0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_32 (SpatialDr (None, 112, 112, 64) 0           activation_66[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_15 (UpSampling2D) (None, 224, 224, 64) 0           spatial_dropout2d_32[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 224, 224, 96) 0           up_sampling2d_15[0][0]
#                                                                  spatial_dropout2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 224, 224, 32) 27680       concatenate_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 224, 224, 32) 128         conv2d_67[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 224, 224, 32) 0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 224, 224, 32) 9248        activation_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 224, 224, 32) 128         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 224, 224, 32) 0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# spatial_dropout2d_33 (SpatialDr (None, 224, 224, 32) 0           activation_68[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 224, 224, 1)  33          spatial_dropout2d_33[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 224, 224, 1)  0           conv2d_69[0][0]
# __________________________________________________________________________________________________
# reshape_3 (Reshape)             (None, 224, 224)     0           activation_69[0][0]
# ==================================================================================================
# Total params: 31,466,753
# Trainable params: 31,454,721
# Non-trainable params: 12,032
# __________________________________________________________________________________________________
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 13s 36ms/step - loss: 0.1616 - iou: 0.8384 - dice_coe: 0.6224 - precision: 0.7400 - recall: 0.7024 - accuracy: 0.8165 - val_loss: 0.4749 - val_iou: 0.5251 - val_dice_coe: 0.4750 - val_precision: 0.3131 - val_recall: 1.0000 - val_accuracy: 0.3131
# Epoch 2/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0994 - iou: 0.9006 - dice_coe: 0.7406 - precision: 0.8557 - recall: 0.7994 - accuracy: 0.8897 - val_loss: 0.4730 - val_iou: 0.5270 - val_dice_coe: 0.4767 - val_precision: 0.3143 - val_recall: 1.0000 - val_accuracy: 0.3171
# Epoch 3/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0891 - iou: 0.9109 - dice_coe: 0.7741 - precision: 0.8845 - recall: 0.8088 - accuracy: 0.9015 - val_loss: 0.4351 - val_iou: 0.5649 - val_dice_coe: 0.5030 - val_precision: 0.3407 - val_recall: 0.9804 - val_accuracy: 0.3975
# Epoch 4/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0858 - iou: 0.9142 - dice_coe: 0.7886 - precision: 0.8689 - recall: 0.8275 - accuracy: 0.9013 - val_loss: 0.4654 - val_iou: 0.5346 - val_dice_coe: 0.4818 - val_precision: 0.3181 - val_recall: 1.0000 - val_accuracy: 0.3295
# Epoch 5/100
# 360/360 [==============================] - 5s 15ms/step - loss: 0.0860 - iou: 0.9140 - dice_coe: 0.7850 - precision: 0.8741 - recall: 0.8259 - accuracy: 0.9032 - val_loss: 0.4108 - val_iou: 0.5892 - val_dice_coe: 0.5200 - val_precision: 0.3519 - val_recall: 0.9998 - val_accuracy: 0.4239
# Epoch 6/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0829 - iou: 0.9171 - dice_coe: 0.7970 - precision: 0.8725 - recall: 0.8366 - accuracy: 0.9057 - val_loss: 0.3995 - val_iou: 0.6005 - val_dice_coe: 0.5293 - val_precision: 0.3582 - val_recall: 0.9978 - val_accuracy: 0.4409
# Epoch 7/100
# 360/360 [==============================] - 5s 15ms/step - loss: 0.0809 - iou: 0.9191 - dice_coe: 0.8019 - precision: 0.8942 - recall: 0.8145 - accuracy: 0.9057 - val_loss: 0.1446 - val_iou: 0.8554 - val_dice_coe: 0.7507 - val_precision: 0.7074 - val_recall: 0.8277 - val_accuracy: 0.8379
# Epoch 8/100
# 360/360 [==============================] - 5s 15ms/step - loss: 0.0769 - iou: 0.9231 - dice_coe: 0.8153 - precision: 0.8831 - recall: 0.8498 - accuracy: 0.9142 - val_loss: 0.0902 - val_iou: 0.9098 - val_dice_coe: 0.8175 - val_precision: 0.8611 - val_recall: 0.8143 - val_accuracy: 0.8997
# Epoch 9/100
# 360/360 [==============================] - 5s 15ms/step - loss: 0.0746 - iou: 0.9254 - dice_coe: 0.8235 - precision: 0.8768 - recall: 0.8554 - accuracy: 0.9127 - val_loss: 0.1343 - val_iou: 0.8657 - val_dice_coe: 0.7745 - val_precision: 0.7256 - val_recall: 0.8555 - val_accuracy: 0.8512
# Epoch 10/100
# 360/360 [==============================] - 5s 15ms/step - loss: 0.0825 - iou: 0.9175 - dice_coe: 0.8040 - precision: 0.8705 - recall: 0.8346 - accuracy: 0.9037 - val_loss: 0.1803 - val_iou: 0.8197 - val_dice_coe: 0.7237 - val_precision: 0.6215 - val_recall: 0.8877 - val_accuracy: 0.7949
# Epoch 11/100
# 360/360 [==============================] - 5s 15ms/step - loss: 0.0883 - iou: 0.9117 - dice_coe: 0.7898 - precision: 0.8813 - recall: 0.8069 - accuracy: 0.8964 - val_loss: 0.1867 - val_iou: 0.8133 - val_dice_coe: 0.7254 - val_precision: 0.6065 - val_recall: 0.9309 - val_accuracy: 0.7831
# Epoch 12/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0731 - iou: 0.9269 - dice_coe: 0.8256 - precision: 0.9097 - recall: 0.8251 - accuracy: 0.9151 - val_loss: 0.0952 - val_iou: 0.9048 - val_dice_coe: 0.8367 - val_precision: 0.7632 - val_recall: 0.9408 - val_accuracy: 0.8902
# Epoch 13/100
# 360/360 [==============================] - 5s 15ms/step - loss: 0.0704 - iou: 0.9296 - dice_coe: 0.8324 - precision: 0.9025 - recall: 0.8477 - accuracy: 0.9188 - val_loss: 0.0890 - val_iou: 0.9110 - val_dice_coe: 0.8265 - val_precision: 0.9396 - val_recall: 0.7615 - val_accuracy: 0.9081
# Epoch 14/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0699 - iou: 0.9301 - dice_coe: 0.8286 - precision: 0.9089 - recall: 0.8490 - accuracy: 0.9206 - val_loss: 0.0874 - val_iou: 0.9126 - val_dice_coe: 0.8188 - val_precision: 0.9501 - val_recall: 0.7382 - val_accuracy: 0.9042
# Epoch 15/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0696 - iou: 0.9304 - dice_coe: 0.8404 - precision: 0.8861 - recall: 0.8761 - accuracy: 0.9192 - val_loss: 0.1070 - val_iou: 0.8930 - val_dice_coe: 0.8056 - val_precision: 0.7283 - val_recall: 0.9237 - val_accuracy: 0.8664
# Epoch 16/100
# 360/360 [==============================] - 5s 15ms/step - loss: 0.0661 - iou: 0.9339 - dice_coe: 0.8386 - precision: 0.9235 - recall: 0.8430 - accuracy: 0.9248 - val_loss: 0.2436 - val_iou: 0.7564 - val_dice_coe: 0.6609 - val_precision: 0.4990 - val_recall: 0.9809 - val_accuracy: 0.6859
# Epoch 17/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0679 - iou: 0.9321 - dice_coe: 0.8400 - precision: 0.8974 - recall: 0.8652 - accuracy: 0.9227 - val_loss: 0.2140 - val_iou: 0.7860 - val_dice_coe: 0.6834 - val_precision: 0.5603 - val_recall: 0.9069 - val_accuracy: 0.7436
# Epoch 18/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0653 - iou: 0.9347 - dice_coe: 0.8439 - precision: 0.9087 - recall: 0.8607 - accuracy: 0.9255 - val_loss: 0.0737 - val_iou: 0.9263 - val_dice_coe: 0.8629 - val_precision: 0.8097 - val_recall: 0.9459 - val_accuracy: 0.9131
# Epoch 19/100
# 360/360 [==============================] - 5s 15ms/step - loss: 0.0619 - iou: 0.9381 - dice_coe: 0.8522 - precision: 0.9149 - recall: 0.8698 - accuracy: 0.9298 - val_loss: 0.0909 - val_iou: 0.9091 - val_dice_coe: 0.7951 - val_precision: 0.9607 - val_recall: 0.7028 - val_accuracy: 0.8959
# Epoch 20/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0638 - iou: 0.9362 - dice_coe: 0.8516 - precision: 0.9055 - recall: 0.8666 - accuracy: 0.9266 - val_loss: 0.0875 - val_iou: 0.9125 - val_dice_coe: 0.8175 - val_precision: 0.9718 - val_recall: 0.7167 - val_accuracy: 0.9036
# Epoch 21/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0621 - iou: 0.9379 - dice_coe: 0.8526 - precision: 0.9094 - recall: 0.8713 - accuracy: 0.9283 - val_loss: 0.1096 - val_iou: 0.8904 - val_dice_coe: 0.8127 - val_precision: 0.7332 - val_recall: 0.9532 - val_accuracy: 0.8785
# Epoch 22/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0677 - iou: 0.9323 - dice_coe: 0.8388 - precision: 0.9131 - recall: 0.8479 - accuracy: 0.9230 - val_loss: 0.1591 - val_iou: 0.8409 - val_dice_coe: 0.7492 - val_precision: 0.6187 - val_recall: 0.9666 - val_accuracy: 0.8022
# Epoch 23/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0600 - iou: 0.9400 - dice_coe: 0.8599 - precision: 0.9124 - recall: 0.8812 - accuracy: 0.9321 - val_loss: 0.1451 - val_iou: 0.8549 - val_dice_coe: 0.7611 - val_precision: 0.6472 - val_recall: 0.9598 - val_accuracy: 0.8249
# Epoch 24/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0586 - iou: 0.9414 - dice_coe: 0.8573 - precision: 0.9214 - recall: 0.8749 - accuracy: 0.9341 - val_loss: 0.2174 - val_iou: 0.7826 - val_dice_coe: 0.6941 - val_precision: 0.5354 - val_recall: 0.9884 - val_accuracy: 0.7295
# Epoch 25/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0627 - iou: 0.9373 - dice_coe: 0.8501 - precision: 0.9200 - recall: 0.8546 - accuracy: 0.9278 - val_loss: 0.0938 - val_iou: 0.9062 - val_dice_coe: 0.8088 - val_precision: 0.8599 - val_recall: 0.7810 - val_accuracy: 0.8912
# Epoch 26/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0611 - iou: 0.9389 - dice_coe: 0.8559 - precision: 0.9167 - recall: 0.8658 - accuracy: 0.9295 - val_loss: 0.1451 - val_iou: 0.8549 - val_dice_coe: 0.7502 - val_precision: 0.6617 - val_recall: 0.9280 - val_accuracy: 0.8304
# Epoch 27/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0620 - iou: 0.9380 - dice_coe: 0.8543 - precision: 0.9099 - recall: 0.8700 - accuracy: 0.9291 - val_loss: 0.0976 - val_iou: 0.9024 - val_dice_coe: 0.8055 - val_precision: 0.7673 - val_recall: 0.9347 - val_accuracy: 0.8907
# Epoch 28/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0635 - iou: 0.9365 - dice_coe: 0.8516 - precision: 0.9176 - recall: 0.8588 - accuracy: 0.9277 - val_loss: 0.2959 - val_iou: 0.7041 - val_dice_coe: 0.5998 - val_precision: 0.4448 - val_recall: 0.9342 - val_accuracy: 0.6146
# Epoch 29/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0710 - iou: 0.9290 - dice_coe: 0.8324 - precision: 0.8949 - recall: 0.8453 - accuracy: 0.9148 - val_loss: 0.2182 - val_iou: 0.7818 - val_dice_coe: 0.6711 - val_precision: 0.5555 - val_recall: 0.8806 - val_accuracy: 0.7422
# Epoch 30/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0618 - iou: 0.9382 - dice_coe: 0.8534 - precision: 0.9110 - recall: 0.8682 - accuracy: 0.9288 - val_loss: 0.1112 - val_iou: 0.8888 - val_dice_coe: 0.8181 - val_precision: 0.7253 - val_recall: 0.9681 - val_accuracy: 0.8765
# Epoch 31/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0562 - iou: 0.9438 - dice_coe: 0.8659 - precision: 0.9203 - recall: 0.8803 - accuracy: 0.9361 - val_loss: 0.1003 - val_iou: 0.8997 - val_dice_coe: 0.8264 - val_precision: 0.7319 - val_recall: 0.9707 - val_accuracy: 0.8796
# Epoch 32/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0537 - iou: 0.9463 - dice_coe: 0.8753 - precision: 0.9277 - recall: 0.8910 - accuracy: 0.9401 - val_loss: 0.0611 - val_iou: 0.9389 - val_dice_coe: 0.8835 - val_precision: 0.8501 - val_recall: 0.9532 - val_accuracy: 0.9326
# Epoch 33/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0549 - iou: 0.9451 - dice_coe: 0.8689 - precision: 0.9242 - recall: 0.8845 - accuracy: 0.9374 - val_loss: 0.0508 - val_iou: 0.9492 - val_dice_coe: 0.8935 - val_precision: 0.9302 - val_recall: 0.8763 - val_accuracy: 0.9416
# Epoch 34/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0539 - iou: 0.9461 - dice_coe: 0.8708 - precision: 0.9129 - recall: 0.8977 - accuracy: 0.9372 - val_loss: 0.0405 - val_iou: 0.9595 - val_dice_coe: 0.9075 - val_precision: 0.9474 - val_recall: 0.8985 - val_accuracy: 0.9517
# Epoch 35/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0559 - iou: 0.9441 - dice_coe: 0.8670 - precision: 0.9317 - recall: 0.8774 - accuracy: 0.9366 - val_loss: 0.0507 - val_iou: 0.9493 - val_dice_coe: 0.8881 - val_precision: 0.9521 - val_recall: 0.8561 - val_accuracy: 0.9401
# Epoch 36/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0536 - iou: 0.9464 - dice_coe: 0.8731 - precision: 0.9156 - recall: 0.8923 - accuracy: 0.9378 - val_loss: 0.0521 - val_iou: 0.9479 - val_dice_coe: 0.8903 - val_precision: 0.9270 - val_recall: 0.8775 - val_accuracy: 0.9394
# Epoch 37/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0530 - iou: 0.9470 - dice_coe: 0.8741 - precision: 0.9215 - recall: 0.8905 - accuracy: 0.9389 - val_loss: 0.0411 - val_iou: 0.9589 - val_dice_coe: 0.9171 - val_precision: 0.9175 - val_recall: 0.9425 - val_accuracy: 0.9543
# Epoch 38/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0497 - iou: 0.9503 - dice_coe: 0.8771 - precision: 0.9389 - recall: 0.8906 - accuracy: 0.9448 - val_loss: 0.0520 - val_iou: 0.9480 - val_dice_coe: 0.8907 - val_precision: 0.8974 - val_recall: 0.9096 - val_accuracy: 0.9389
# Epoch 39/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0517 - iou: 0.9483 - dice_coe: 0.8799 - precision: 0.9248 - recall: 0.8951 - accuracy: 0.9406 - val_loss: 0.0468 - val_iou: 0.9532 - val_dice_coe: 0.8964 - val_precision: 0.9746 - val_recall: 0.8437 - val_accuracy: 0.9438
# Epoch 40/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0490 - iou: 0.9510 - dice_coe: 0.8834 - precision: 0.9301 - recall: 0.8975 - accuracy: 0.9444 - val_loss: 0.0459 - val_iou: 0.9541 - val_dice_coe: 0.9084 - val_precision: 0.8858 - val_recall: 0.9606 - val_accuracy: 0.9478
# Epoch 41/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0494 - iou: 0.9506 - dice_coe: 0.8826 - precision: 0.9310 - recall: 0.8949 - accuracy: 0.9444 - val_loss: 0.0478 - val_iou: 0.9522 - val_dice_coe: 0.8932 - val_precision: 0.9309 - val_recall: 0.8956 - val_accuracy: 0.9446
# Epoch 42/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0508 - iou: 0.9492 - dice_coe: 0.8771 - precision: 0.9333 - recall: 0.8897 - accuracy: 0.9422 - val_loss: 0.0586 - val_iou: 0.9414 - val_dice_coe: 0.8872 - val_precision: 0.8462 - val_recall: 0.9522 - val_accuracy: 0.9298
# Epoch 43/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0544 - iou: 0.9456 - dice_coe: 0.8767 - precision: 0.9243 - recall: 0.8905 - accuracy: 0.9392 - val_loss: 0.0509 - val_iou: 0.9491 - val_dice_coe: 0.8996 - val_precision: 0.8744 - val_recall: 0.9563 - val_accuracy: 0.9428
# Epoch 44/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0537 - iou: 0.9463 - dice_coe: 0.8765 - precision: 0.9356 - recall: 0.8784 - accuracy: 0.9382 - val_loss: 0.0743 - val_iou: 0.9257 - val_dice_coe: 0.8601 - val_precision: 0.7879 - val_recall: 0.9724 - val_accuracy: 0.9095
# Epoch 45/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0532 - iou: 0.9468 - dice_coe: 0.8753 - precision: 0.9248 - recall: 0.8925 - accuracy: 0.9398 - val_loss: 0.1684 - val_iou: 0.8316 - val_dice_coe: 0.7465 - val_precision: 0.6129 - val_recall: 0.9924 - val_accuracy: 0.8029
# Epoch 46/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0528 - iou: 0.9472 - dice_coe: 0.8792 - precision: 0.9195 - recall: 0.8990 - accuracy: 0.9400 - val_loss: 0.0667 - val_iou: 0.9333 - val_dice_coe: 0.8678 - val_precision: 0.9434 - val_recall: 0.8110 - val_accuracy: 0.9246
# Epoch 47/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0483 - iou: 0.9517 - dice_coe: 0.8839 - precision: 0.9350 - recall: 0.8949 - accuracy: 0.9448 - val_loss: 0.0648 - val_iou: 0.9352 - val_dice_coe: 0.8603 - val_precision: 0.8750 - val_recall: 0.9073 - val_accuracy: 0.9289
# Epoch 48/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0470 - iou: 0.9530 - dice_coe: 0.8893 - precision: 0.9399 - recall: 0.8957 - accuracy: 0.9466 - val_loss: 0.0580 - val_iou: 0.9420 - val_dice_coe: 0.8810 - val_precision: 0.8936 - val_recall: 0.9083 - val_accuracy: 0.9358
# Epoch 49/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0525 - iou: 0.9475 - dice_coe: 0.8780 - precision: 0.9280 - recall: 0.8908 - accuracy: 0.9402 - val_loss: 0.0855 - val_iou: 0.9145 - val_dice_coe: 0.8455 - val_precision: 0.7628 - val_recall: 0.9711 - val_accuracy: 0.8967
# Epoch 50/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0465 - iou: 0.9535 - dice_coe: 0.8891 - precision: 0.9366 - recall: 0.9015 - accuracy: 0.9476 - val_loss: 0.1525 - val_iou: 0.8475 - val_dice_coe: 0.7571 - val_precision: 0.6423 - val_recall: 0.9872 - val_accuracy: 0.8228
# Epoch 51/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0484 - iou: 0.9516 - dice_coe: 0.8891 - precision: 0.9327 - recall: 0.8999 - accuracy: 0.9448 - val_loss: 0.0588 - val_iou: 0.9412 - val_dice_coe: 0.8827 - val_precision: 0.8384 - val_recall: 0.9781 - val_accuracy: 0.9336
# Epoch 52/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0517 - iou: 0.9483 - dice_coe: 0.8772 - precision: 0.9290 - recall: 0.8898 - accuracy: 0.9402 - val_loss: 0.0489 - val_iou: 0.9511 - val_dice_coe: 0.8990 - val_precision: 0.9069 - val_recall: 0.9145 - val_accuracy: 0.9440
# Epoch 53/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0508 - iou: 0.9492 - dice_coe: 0.8794 - precision: 0.9274 - recall: 0.8955 - accuracy: 0.9422 - val_loss: 0.0393 - val_iou: 0.9607 - val_dice_coe: 0.9165 - val_precision: 0.9202 - val_recall: 0.9428 - val_accuracy: 0.9555
# Epoch 54/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0457 - iou: 0.9543 - dice_coe: 0.8914 - precision: 0.9302 - recall: 0.9103 - accuracy: 0.9482 - val_loss: 0.0446 - val_iou: 0.9554 - val_dice_coe: 0.9063 - val_precision: 0.9280 - val_recall: 0.8990 - val_accuracy: 0.9467
# Epoch 55/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0484 - iou: 0.9516 - dice_coe: 0.8875 - precision: 0.9375 - recall: 0.8904 - accuracy: 0.9450 - val_loss: 0.0596 - val_iou: 0.9404 - val_dice_coe: 0.8674 - val_precision: 0.9810 - val_recall: 0.7889 - val_accuracy: 0.9283
# Epoch 56/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0450 - iou: 0.9550 - dice_coe: 0.8919 - precision: 0.9331 - recall: 0.9112 - accuracy: 0.9492 - val_loss: 0.0425 - val_iou: 0.9575 - val_dice_coe: 0.9029 - val_precision: 0.9524 - val_recall: 0.8808 - val_accuracy: 0.9479
# Epoch 57/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0434 - iou: 0.9566 - dice_coe: 0.8976 - precision: 0.9370 - recall: 0.9125 - accuracy: 0.9508 - val_loss: 0.0433 - val_iou: 0.9567 - val_dice_coe: 0.9021 - val_precision: 0.9753 - val_recall: 0.8656 - val_accuracy: 0.9497
# Epoch 58/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0415 - iou: 0.9585 - dice_coe: 0.9033 - precision: 0.9366 - recall: 0.9177 - accuracy: 0.9530 - val_loss: 0.0371 - val_iou: 0.9629 - val_dice_coe: 0.9137 - val_precision: 0.9334 - val_recall: 0.9345 - val_accuracy: 0.9574
# Epoch 59/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0481 - iou: 0.9519 - dice_coe: 0.8867 - precision: 0.9451 - recall: 0.8878 - accuracy: 0.9448 - val_loss: 0.0537 - val_iou: 0.9463 - val_dice_coe: 0.8877 - val_precision: 0.8821 - val_recall: 0.9249 - val_accuracy: 0.9357
# Epoch 60/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0481 - iou: 0.9519 - dice_coe: 0.8904 - precision: 0.9319 - recall: 0.8998 - accuracy: 0.9452 - val_loss: 0.0476 - val_iou: 0.9524 - val_dice_coe: 0.8972 - val_precision: 0.8717 - val_recall: 0.9544 - val_accuracy: 0.9413
# Epoch 61/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0483 - iou: 0.9517 - dice_coe: 0.8868 - precision: 0.9343 - recall: 0.8989 - accuracy: 0.9441 - val_loss: 0.0658 - val_iou: 0.9342 - val_dice_coe: 0.8635 - val_precision: 0.8434 - val_recall: 0.9401 - val_accuracy: 0.9237
# Epoch 62/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0439 - iou: 0.9561 - dice_coe: 0.8944 - precision: 0.9395 - recall: 0.9067 - accuracy: 0.9495 - val_loss: 0.0796 - val_iou: 0.9204 - val_dice_coe: 0.8478 - val_precision: 0.7956 - val_recall: 0.9458 - val_accuracy: 0.9032
# Epoch 63/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0436 - iou: 0.9564 - dice_coe: 0.8997 - precision: 0.9392 - recall: 0.9086 - accuracy: 0.9504 - val_loss: 0.0378 - val_iou: 0.9622 - val_dice_coe: 0.9121 - val_precision: 0.9474 - val_recall: 0.9112 - val_accuracy: 0.9547
# Epoch 64/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0414 - iou: 0.9586 - dice_coe: 0.9039 - precision: 0.9410 - recall: 0.9147 - accuracy: 0.9533 - val_loss: 0.0348 - val_iou: 0.9652 - val_dice_coe: 0.9235 - val_precision: 0.9219 - val_recall: 0.9505 - val_accuracy: 0.9595
# Epoch 65/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0453 - iou: 0.9547 - dice_coe: 0.8926 - precision: 0.9353 - recall: 0.9008 - accuracy: 0.9475 - val_loss: 0.1698 - val_iou: 0.8302 - val_dice_coe: 0.7349 - val_precision: 0.6170 - val_recall: 0.9817 - val_accuracy: 0.8038
# Epoch 66/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0472 - iou: 0.9528 - dice_coe: 0.8919 - precision: 0.9264 - recall: 0.9113 - accuracy: 0.9461 - val_loss: 0.0575 - val_iou: 0.9425 - val_dice_coe: 0.8793 - val_precision: 0.8855 - val_recall: 0.9137 - val_accuracy: 0.9331
# Epoch 67/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0434 - iou: 0.9566 - dice_coe: 0.8998 - precision: 0.9421 - recall: 0.9074 - accuracy: 0.9510 - val_loss: 0.0518 - val_iou: 0.9482 - val_dice_coe: 0.8832 - val_precision: 0.9564 - val_recall: 0.8544 - val_accuracy: 0.9398
# Epoch 68/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0477 - iou: 0.9523 - dice_coe: 0.8883 - precision: 0.9285 - recall: 0.9038 - accuracy: 0.9454 - val_loss: 0.0428 - val_iou: 0.9572 - val_dice_coe: 0.8989 - val_precision: 0.9352 - val_recall: 0.9034 - val_accuracy: 0.9495
# Epoch 69/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0469 - iou: 0.9531 - dice_coe: 0.8910 - precision: 0.9449 - recall: 0.8954 - accuracy: 0.9473 - val_loss: 0.0680 - val_iou: 0.9320 - val_dice_coe: 0.8682 - val_precision: 0.8973 - val_recall: 0.8720 - val_accuracy: 0.9271
# Epoch 70/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0437 - iou: 0.9563 - dice_coe: 0.9003 - precision: 0.9354 - recall: 0.9149 - accuracy: 0.9507 - val_loss: 0.0372 - val_iou: 0.9628 - val_dice_coe: 0.9204 - val_precision: 0.9168 - val_recall: 0.9485 - val_accuracy: 0.9562
# Epoch 71/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0459 - iou: 0.9541 - dice_coe: 0.8946 - precision: 0.9272 - recall: 0.9107 - accuracy: 0.9470 - val_loss: 0.0467 - val_iou: 0.9533 - val_dice_coe: 0.8917 - val_precision: 0.9666 - val_recall: 0.8438 - val_accuracy: 0.9411
# Epoch 72/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0422 - iou: 0.9578 - dice_coe: 0.8988 - precision: 0.9332 - recall: 0.9195 - accuracy: 0.9520 - val_loss: 0.0398 - val_iou: 0.9602 - val_dice_coe: 0.9101 - val_precision: 0.9522 - val_recall: 0.8954 - val_accuracy: 0.9526
# Epoch 73/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0450 - iou: 0.9550 - dice_coe: 0.8935 - precision: 0.9303 - recall: 0.9096 - accuracy: 0.9476 - val_loss: 0.0436 - val_iou: 0.9564 - val_dice_coe: 0.9009 - val_precision: 0.9735 - val_recall: 0.8591 - val_accuracy: 0.9469
# Epoch 74/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0435 - iou: 0.9565 - dice_coe: 0.8982 - precision: 0.9506 - recall: 0.8989 - accuracy: 0.9501 - val_loss: 0.0617 - val_iou: 0.9383 - val_dice_coe: 0.8680 - val_precision: 0.8963 - val_recall: 0.8980 - val_accuracy: 0.9324
# Epoch 75/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0449 - iou: 0.9551 - dice_coe: 0.8947 - precision: 0.9239 - recall: 0.9164 - accuracy: 0.9480 - val_loss: 0.1079 - val_iou: 0.8921 - val_dice_coe: 0.8074 - val_precision: 0.7295 - val_recall: 0.9765 - val_accuracy: 0.8779
# Epoch 76/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0402 - iou: 0.9598 - dice_coe: 0.9041 - precision: 0.9467 - recall: 0.9128 - accuracy: 0.9545 - val_loss: 0.0365 - val_iou: 0.9635 - val_dice_coe: 0.9038 - val_precision: 0.9490 - val_recall: 0.9241 - val_accuracy: 0.9596
# Epoch 77/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0406 - iou: 0.9594 - dice_coe: 0.9045 - precision: 0.9389 - recall: 0.9175 - accuracy: 0.9540 - val_loss: 0.0514 - val_iou: 0.9486 - val_dice_coe: 0.8878 - val_precision: 0.9096 - val_recall: 0.9277 - val_accuracy: 0.9470
# Epoch 78/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0439 - iou: 0.9561 - dice_coe: 0.8954 - precision: 0.9320 - recall: 0.9146 - accuracy: 0.9498 - val_loss: 0.0334 - val_iou: 0.9666 - val_dice_coe: 0.9242 - val_precision: 0.9454 - val_recall: 0.9297 - val_accuracy: 0.9603
# Epoch 79/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0455 - iou: 0.9545 - dice_coe: 0.8945 - precision: 0.9315 - recall: 0.9085 - accuracy: 0.9483 - val_loss: 0.0392 - val_iou: 0.9608 - val_dice_coe: 0.9178 - val_precision: 0.9487 - val_recall: 0.9127 - val_accuracy: 0.9557
# Epoch 80/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0420 - iou: 0.9580 - dice_coe: 0.8987 - precision: 0.9470 - recall: 0.9071 - accuracy: 0.9520 - val_loss: 0.0470 - val_iou: 0.9530 - val_dice_coe: 0.8970 - val_precision: 0.8792 - val_recall: 0.9681 - val_accuracy: 0.9483
# Epoch 81/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0385 - iou: 0.9615 - dice_coe: 0.9107 - precision: 0.9426 - recall: 0.9240 - accuracy: 0.9566 - val_loss: 0.0984 - val_iou: 0.9016 - val_dice_coe: 0.8311 - val_precision: 0.7425 - val_recall: 0.9887 - val_accuracy: 0.8877
# Epoch 82/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0396 - iou: 0.9604 - dice_coe: 0.9049 - precision: 0.9390 - recall: 0.9243 - accuracy: 0.9557 - val_loss: 0.0556 - val_iou: 0.9444 - val_dice_coe: 0.8695 - val_precision: 0.9031 - val_recall: 0.8979 - val_accuracy: 0.9360
# Epoch 83/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0417 - iou: 0.9583 - dice_coe: 0.9031 - precision: 0.9423 - recall: 0.9111 - accuracy: 0.9526 - val_loss: 0.0438 - val_iou: 0.9562 - val_dice_coe: 0.8919 - val_precision: 0.9148 - val_recall: 0.9347 - val_accuracy: 0.9508
# Epoch 84/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0420 - iou: 0.9580 - dice_coe: 0.9035 - precision: 0.9399 - recall: 0.9149 - accuracy: 0.9538 - val_loss: 0.0368 - val_iou: 0.9632 - val_dice_coe: 0.9191 - val_precision: 0.9435 - val_recall: 0.9135 - val_accuracy: 0.9552
# Epoch 85/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0437 - iou: 0.9563 - dice_coe: 0.8991 - precision: 0.9455 - recall: 0.9007 - accuracy: 0.9502 - val_loss: 0.0434 - val_iou: 0.9566 - val_dice_coe: 0.9032 - val_precision: 0.9557 - val_recall: 0.8786 - val_accuracy: 0.9478
# Epoch 86/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0433 - iou: 0.9567 - dice_coe: 0.9016 - precision: 0.9506 - recall: 0.8969 - accuracy: 0.9500 - val_loss: 0.0463 - val_iou: 0.9537 - val_dice_coe: 0.8916 - val_precision: 0.9671 - val_recall: 0.8510 - val_accuracy: 0.9427
# Epoch 87/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0458 - iou: 0.9542 - dice_coe: 0.8916 - precision: 0.9355 - recall: 0.9040 - accuracy: 0.9479 - val_loss: 0.0596 - val_iou: 0.9404 - val_dice_coe: 0.8609 - val_precision: 0.9239 - val_recall: 0.8570 - val_accuracy: 0.9306
# Epoch 88/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0460 - iou: 0.9540 - dice_coe: 0.8946 - precision: 0.9272 - recall: 0.9107 - accuracy: 0.9471 - val_loss: 0.0415 - val_iou: 0.9585 - val_dice_coe: 0.9064 - val_precision: 0.9520 - val_recall: 0.8891 - val_accuracy: 0.9497
# Epoch 89/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0414 - iou: 0.9586 - dice_coe: 0.9014 - precision: 0.9375 - recall: 0.9181 - accuracy: 0.9530 - val_loss: 0.0354 - val_iou: 0.9646 - val_dice_coe: 0.9189 - val_precision: 0.9573 - val_recall: 0.9024 - val_accuracy: 0.9561
# Epoch 90/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0401 - iou: 0.9599 - dice_coe: 0.9070 - precision: 0.9395 - recall: 0.9219 - accuracy: 0.9547 - val_loss: 0.0823 - val_iou: 0.9177 - val_dice_coe: 0.8499 - val_precision: 0.7893 - val_recall: 0.9632 - val_accuracy: 0.9062
# Epoch 91/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0403 - iou: 0.9597 - dice_coe: 0.9065 - precision: 0.9481 - recall: 0.9132 - accuracy: 0.9542 - val_loss: 0.0345 - val_iou: 0.9655 - val_dice_coe: 0.9235 - val_precision: 0.9328 - val_recall: 0.9395 - val_accuracy: 0.9595
# Epoch 92/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0384 - iou: 0.9616 - dice_coe: 0.9088 - precision: 0.9402 - recall: 0.9264 - accuracy: 0.9570 - val_loss: 0.0715 - val_iou: 0.9285 - val_dice_coe: 0.8626 - val_precision: 0.8165 - val_recall: 0.9517 - val_accuracy: 0.9149
# Epoch 93/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0410 - iou: 0.9590 - dice_coe: 0.9032 - precision: 0.9311 - recall: 0.9221 - accuracy: 0.9522 - val_loss: 0.0315 - val_iou: 0.9685 - val_dice_coe: 0.9252 - val_precision: 0.9496 - val_recall: 0.9298 - val_accuracy: 0.9619
# Epoch 94/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0383 - iou: 0.9617 - dice_coe: 0.9118 - precision: 0.9417 - recall: 0.9269 - accuracy: 0.9569 - val_loss: 0.0397 - val_iou: 0.9603 - val_dice_coe: 0.9116 - val_precision: 0.9060 - val_recall: 0.9530 - val_accuracy: 0.9539
# Epoch 95/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0394 - iou: 0.9606 - dice_coe: 0.9071 - precision: 0.9476 - recall: 0.9170 - accuracy: 0.9557 - val_loss: 0.0429 - val_iou: 0.9571 - val_dice_coe: 0.9052 - val_precision: 0.9209 - val_recall: 0.9276 - val_accuracy: 0.9524
# Epoch 96/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0412 - iou: 0.9588 - dice_coe: 0.9047 - precision: 0.9349 - recall: 0.9184 - accuracy: 0.9526 - val_loss: 0.0546 - val_iou: 0.9454 - val_dice_coe: 0.8775 - val_precision: 0.9446 - val_recall: 0.8582 - val_accuracy: 0.9381
# Epoch 97/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0441 - iou: 0.9559 - dice_coe: 0.8952 - precision: 0.9373 - recall: 0.9088 - accuracy: 0.9501 - val_loss: 0.0615 - val_iou: 0.9385 - val_dice_coe: 0.8781 - val_precision: 0.8625 - val_recall: 0.9290 - val_accuracy: 0.9311
# Epoch 98/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0407 - iou: 0.9593 - dice_coe: 0.9041 - precision: 0.9518 - recall: 0.9051 - accuracy: 0.9531 - val_loss: 0.0447 - val_iou: 0.9553 - val_dice_coe: 0.8948 - val_precision: 0.9189 - val_recall: 0.9240 - val_accuracy: 0.9490
# Epoch 99/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0363 - iou: 0.9637 - dice_coe: 0.9145 - precision: 0.9410 - recall: 0.9352 - accuracy: 0.9596 - val_loss: 0.0484 - val_iou: 0.9516 - val_dice_coe: 0.8998 - val_precision: 0.9153 - val_recall: 0.9148 - val_accuracy: 0.9447
# Epoch 100/100
# 360/360 [==============================] - 6s 15ms/step - loss: 0.0386 - iou: 0.9614 - dice_coe: 0.9110 - precision: 0.9387 - recall: 0.9270 - accuracy: 0.9563 - val_loss: 0.0495 - val_iou: 0.9505 - val_dice_coe: 0.9006 - val_precision: 0.8837 - val_recall: 0.9518 - val_accuracy: 0.9442

# %%
model_1 = Model(inputs, pred, name="UNET_224")
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coe, precision, recall, accuracy])

# %%
model_1.load_weights('unet_100_epoch.h5')

# %% [markdown]
# ![](http://)Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 9ms/step
# ________________________
# IOU:       |   94.70  |
# Dice Coef: |   89.86  |
# Precision: |   86.96  |
# Recall:    |   96.29  |
# Accuracy:  |   94.26  |
# Loss:      |   5.30  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 0s 5ms/step
# ________________________
# IOU:       |   92.85  |
# Dice Coef: |   86.90  |
# Precision: |   83.81  |
# Recall:    |   93.09  |
# Accuracy:  |   92.30  |
# Loss:      |   7.15  |
# ________________________

# %% [markdown]
# ### Plotting Training Stats

# %% [markdown]
# ## Visualising Predicted Lesions

# %%
plt.figure(figsize=(20, 7))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(1,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(1,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.show()

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224, 224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,224,224,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(224,224), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,224,224,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(224,224), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.

# %% [markdown]
# ### **de nada!**
