# %% [markdown]
# ## Importing the Libraries

# %%
from keras.models import Model, Sequential
from keras.layers import Activation, Dense, BatchNormalization, Dropout, Conv2D, Conv2DTranspose, MaxPooling2D, UpSampling2D, Input, Reshape
from keras.callbacks import EarlyStopping
from keras import backend as K
from keras.optimizers import Adam
import tensorflow as tf
import numpy as np
import pandas as pd
import glob
import PIL
from PIL import Image
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from warnings import filterwarnings

filterwarnings('ignore')
plt.rcParams["axes.grid"] = False
np.random.seed(101)
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Loading the Data

# %% [markdown]
# Defining a function to load the data in sorted order

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
filelist_trainx = sorted(glob.glob('../input/*/trainx/*.bmp'), key=numericalSort)
X_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainx])

filelist_trainy = sorted(glob.glob('../input/*/trainy/*.bmp'), key=numericalSort)
Y_train = np.array([np.array(Image.open(fname)) for fname in filelist_trainy])

# %% [markdown]
# Splitting the dataset into training set and test set to verify our model performance without any bias.

# %%
x_train, x_test, y_train, y_test = train_test_split(X_train, Y_train, test_size = 0.25, random_state = 101)

# %% [markdown]
# Let's plot an image to see how the original images look.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(X_train[0])
plt.subplot(2,4,2)
plt.imshow(X_train[3])
plt.subplot(2,4,3)
plt.imshow(X_train[54])
plt.subplot(2,4,4)
plt.imshow(X_train[77])
plt.subplot(2,4,5)
plt.imshow(X_train[100])
plt.subplot(2,4,6)
plt.imshow(X_train[125])
plt.subplot(2,4,7)
plt.imshow(X_train[130])
plt.subplot(2,4,8)
plt.imshow(X_train[149])
plt.show()

# %% [markdown]
# Now let's see their corresponding masks.

# %%
plt.figure(figsize=(20,9))
plt.subplot(2,4,1)
plt.imshow(Y_train[0], cmap = plt.cm.binary_r)
plt.subplot(2,4,2)
plt.imshow(Y_train[3], cmap = plt.cm.binary_r)
plt.subplot(2,4,3)
plt.imshow(Y_train[54], cmap = plt.cm.binary_r)
plt.subplot(2,4,4)
plt.imshow(Y_train[77], cmap = plt.cm.binary_r)
plt.subplot(2,4,5)
plt.imshow(Y_train[100], cmap = plt.cm.binary_r)
plt.subplot(2,4,6)
plt.imshow(Y_train[125], cmap = plt.cm.binary_r)
plt.subplot(2,4,7)
plt.imshow(Y_train[130], cmap = plt.cm.binary_r)
plt.subplot(2,4,8)
plt.imshow(Y_train[149], cmap = plt.cm.binary_r)
plt.show()

# %% [markdown]
# ## Defining the Loss Function

# %% [markdown]
# #### Jaccard Distance
# The Jaccard distance, which measures dissimilarity between sample sets, is complementary to the Jaccard coefficient and is obtained by subtracting the Jaccard coefficient from 1, or, equivalently, by dividing the difference of the sizes of the union and the intersection of two sets by the size of the union:

# %% [markdown]
# ![jd](https://www.geeksforgeeks.org/wp-content/ql-cache/quicklatex.com-44046533fcd54e98cb53619b3390e083_l3.svg)

# %%
def jaccard_distance(y_true, y_pred, smooth=100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return (1 - jac)

# %% [markdown]
# ## Defining Evaluation Metrics

# %% [markdown]
# #### Intersection over Union
# The Jaccard index, also known as Intersection over Union and the Jaccard similarity coefficient is a statistic used for gauging the similarity and diversity of sample sets. The Jaccard coefficient measures similarity between finite sample sets, and is defined as the size of the intersection divided by the size of the union of the sample sets:

# %% [markdown]
# ![iou](https://www.d2l.ai/_images/iou.svg)

# %%
def iou(y_true, y_pred, smooth = 100):
    intersection = K.sum(K.abs(y_true * y_pred), axis=-1)
    sum_ = K.sum(K.square(y_true), axis = -1) + K.sum(K.square(y_pred), axis=-1)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %% [markdown]
# #### Dice coefficient
# The Dice score is not only a measure of how many positives you find, but it also penalizes for the false positives that the method finds, similar to precision. so it is more similar to precision than accuracy.

# %% [markdown]
# ![dc](https://cdn-images-1.medium.com/max/1600/1*Z1hkDvyhFBogT9EkzVkX2A.png)

# %%
def dice_coef(y_true, y_pred, smooth = 100):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

# %% [markdown]
# #### Precision
# Precision is a good measure to determine, when the costs of False Positive is high.

# %% [markdown]
# ![precsion](https://wikimedia.org/api/rest_v1/media/math/render/svg/26106935459abe7c266f7b1ebfa2a824b334c807)

# %%
def precision(y_true, y_pred):
    '''Calculates the precision, a metric for multi-label classification of
    how many selected items are relevant.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

# %% [markdown]
# #### Recall
# Recall actually calculates how many of the Actual Positives our model capture through labeling it as Positive (True Positive). Applying the same understanding, we know that Recall shall be the model metric we use to select our best model when there is a high cost associated with False Negative.

# %% [markdown]
# ![recall](https://wikimedia.org/api/rest_v1/media/math/render/svg/4c233366865312bc99c832d1475e152c5074891b)

# %%
def recall(y_true, y_pred):
    '''Calculates the recall, a metric for multi-label classification of
    how many relevant items are selected.
    '''
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %% [markdown]
# #### Accuracy

# %%
def accuracy(y_true, y_pred):
    '''Calculates the mean accuracy rate across all predictions for binary
    classification problems.
    '''
    return K.mean(K.equal(y_true, K.round(y_pred)))

# %% [markdown]
# ## Image Augmentation
# To build a powerful image classifier using very little training data, image augmentation is usually required to boost the performance of deep networks. Image augmentation artificially creates training images through different ways of processing or combination of multiple processing, such as random rotation, shifts, shear and flips, etc.

# %% [markdown]
# We are going to define to methods for augmentation, one for **random rotation** and one for **horizontal flipping**

# %%
def random_rotation(x_image, y_image):
    rows_x,cols_x, chl_x = x_image.shape
    rows_y,cols_y = y_image.shape
    rand_num = np.random.randint(-40,40)
    M1 = cv2.getRotationMatrix2D((cols_x/2,rows_x/2),rand_num,1)
    M2 = cv2.getRotationMatrix2D((cols_y/2,rows_y/2),rand_num,1)
    x_image = cv2.warpAffine(x_image,M1,(cols_x,rows_x))
    y_image = cv2.warpAffine(y_image.astype('float32'),M2,(cols_y,rows_y))
    return x_image, y_image.astype('int')

def horizontal_flip(x_image, y_image):
    x_image = cv2.flip(x_image, 1)
    y_image = cv2.flip(y_image.astype('float32'), 1)
    return x_image, y_image.astype('int')

# %%
def img_augmentation(x_train, y_train):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_train)):
        x,y = random_rotation(x_train[idx], y_train[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_train[idx], y_train[idx])
        x_flip.append(x)
        y_flip.append(y)
        return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %%
def img_augmentation(x_test, y_test):
    x_rotat = []
    y_rotat = []
    x_flip = []
    y_flip = []
    x_nois = []
    for idx in range(len(x_test)):
        x,y = random_rotation(x_test[idx], y_test[idx])
        x_rotat.append(x)
        y_rotat.append(y)
        
        x,y = horizontal_flip(x_test[idx], y_test[idx])
        x_flip.append(x)
        y_flip.append(y)

    return np.array(x_rotat), np.array(y_rotat), np.array(x_flip), np.array(y_flip)

# %% [markdown]
# calling the functions for the training data.

# %%
x_rotated, y_rotated, x_flipped, y_flipped = img_augmentation(x_train, y_train)
x_rotated_t, y_rotated_t, x_flipped_t, y_flipped_t = img_augmentation(x_test, y_test)

# %% [markdown]
# Let us have a look at our transformations.

# %%
img_num = 114
plt.figure(figsize=(12,12))
plt.subplot(3,2,1)
plt.imshow(x_train[img_num])
plt.title('Original Image')
plt.subplot(3,2,2)
plt.imshow(y_train[img_num], plt.cm.binary_r)
plt.title('Original Mask')
plt.subplot(3,2,3)
plt.imshow(x_rotated[img_num])
plt.title('Rotated Image')
plt.subplot(3,2,4)
plt.imshow(y_rotated[img_num], plt.cm.binary_r)
plt.title('Rotated Mask')
plt.subplot(3,2,5)
plt.imshow(x_flipped[img_num])
plt.title('Flipped Image')
plt.subplot(3,2,6)
plt.imshow(y_flipped[img_num], plt.cm.binary_r)
plt.title('Flipped Mask')
plt.show()

# %% [markdown]
# Now we join all the augmentations image arrays to the original training arrays.

# %%
# For training Set
x_train_full = np.concatenate([x_train, x_rotated, x_flipped])
y_train_full = np.concatenate([y_train, y_rotated, y_flipped])

# %% [markdown]
# #### Making a Validation Set
# We will split our full training set into train and validation set.
# Validation dataset is used to validate the performance after each epoch.

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_full, y_train_full, test_size = 0.20, random_state = 101)

# %%
print("Length of the Training Set   : {}".format(len(x_train)))
print("Length of the Test Set       : {}".format(len(x_test)))
print("Length of the Validation Set : {}".format(len(x_val)))
# Out:
# Length of the Training Set   : 360
# Length of the Test Set       : 50
# Length of the Validation Set : 90

# %% [markdown]
# ## The Model

# %% [markdown]
# Defining the model in a function which takes two arguments when called
# * **epoch_num**: number of epochs to run
# * **savename**: the name of the model for saving after training

# %% [markdown]
# #### Optimizer and Learning Rate
# * We adopt adam optimization algorithm or adaptive moments, to adjust the learning rate.
# * It is well known that learning rate is one of the critical hyperparameters that have a signiﬁcant impact on classiﬁcation performance.
# * Advantages of Adam optimizer are:
#     - Relatively low memory requirements (though higher than gradient descent and gradient descent with momentum).
#     - Usually works well even with a little tuning of hyperparameter
# * Adam is fairly robust to the choice of hyperparameters, and set the learning rate **α** as 0.003 to speed up the training procedure in this study as advised in the paper [here](https://arxiv.org/pdf/1703.05165v2.pdf)

# %% [markdown]
# ### Model Function

# %% [markdown]
# ![arch](https://raw.githubusercontent.com/hashbanger/Skin_Lesion_Segmentation/master/graphics/fcn_arch.png)

# %%
def fcn_net(epochs_num,savename):

    # Convolution Layers (BatchNorm after non-linear activation)

    img_input = Input(shape= (192, 256, 3))
    x = Conv2D(16, (5, 5), padding='same', name='conv1',strides= (1,1))(img_input)
    x = BatchNormalization(name='bn1')(x)
    x = Activation('relu')(x)
    x = Conv2D(32, (3, 3), padding='same', name='conv2')(x)
    x = BatchNormalization(name='bn2')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    x = Conv2D(64, (4, 4), padding='same', name='conv3')(x)
    x = BatchNormalization(name='bn3')(x)
    x = Activation('relu')(x)
    x = Conv2D(64, (4, 4), padding='same', name='conv4')(x)
    x = BatchNormalization(name='bn4')(x)
    x = Activation('relu')(x)
    x = MaxPooling2D()(x)
    
    x = Dropout(0.5)(x)
    
    x = Conv2D(512, (3, 3), padding='same', name='conv5')(x)
    x = BatchNormalization(name='bn5')(x)
    x = Activation('relu')(x)
    x = Dense(1024, activation = 'relu', name='fc1')(x)
    x = Dense(1024, activation = 'relu', name='fc2')(x)

    # Deconvolution Layers (BatchNorm after non-linear activation)

    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv1')(x)
    x = BatchNormalization(name='bn6')(x)
    x = Activation('relu')(x)
    x = UpSampling2D()(x)
    x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv2')(x)
    x = BatchNormalization(name='bn7')(x)
    x = Activation('relu')(x)
    x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv3')(x)
    x = BatchNormalization(name='bn8')(x)
    x = Activation('relu')(x)
    x = UpSampling2D()(x)
    x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv4')(x)
    x = BatchNormalization(name='bn9')(x)
    
    x = Dropout(0.5)(x)

    x = Activation('sigmoid')(x)
    pred = Reshape((192,256))(x)
    
    model = Model(inputs=img_input, outputs=pred)
    
    model.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance]
                  , metrics=[iou, dice_coef, precision, recall, accuracy])

    hist = model.fit(x_train, y_train, epochs= epochs_num, batch_size= 18, validation_data= (x_val, y_val), verbose=1)

    model.save(savename)
    return model,hist

# %% [markdown]
# <font color='red'>**Problems In Guided Dropout Implementation**
#
# - The entire network architecture is implemented using Keras.
# - Now to implement the Guided Dropout Layer using Keras we have to know the detailed backend of the Keras Library because:
# - We should know in what form the inputs will be coming to our layer so we could manipulate them.
# - We should also know in what form the output should be given to the next layer.
# - If we implement Guided Dropout from scratch then we will have to implement entire architecture from scratch which will be neither efficient nor easily feasible.</font>

# %% [markdown]
# **After 1 epoch**

# %%
model, hist = fcn_net(epochs_num= 1, savename= 'fcn_1_epochs.h5')
# Out:
# Train on 360 samples, validate on 90 samples
# Epoch 1/1
# 360/360 [==============================] - 12s 33ms/step - loss: 0.2575 - iou: 0.7425 - dice_coef: 0.5039 - precision: 0.7250 - recall: 0.3743 - accuracy: 0.7457 - val_loss: 0.4808 - val_iou: 0.5192 - val_dice_coef: 0.4453 - val_precision: 0.3003 - val_recall: 0.8493 - val_accuracy: 0.3347

# %% [markdown]
# ## Loading the Model

# %% [markdown]
# Here we can load a pretrained model

# %%
img_input = Input(shape= (192, 256, 3))
x = Conv2D(16, (5, 5), padding='same', name='conv1',strides= (1,1))(img_input)
x = BatchNormalization(name='bn1')(x)
x = Activation('relu')(x)
x = Conv2D(32, (3, 3), padding='same', name='conv2')(x)
x = BatchNormalization(name='bn2')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)
x = Conv2D(64, (4, 4), padding='same', name='conv3')(x)
x = BatchNormalization(name='bn3')(x)
x = Activation('relu')(x)
x = Conv2D(64, (4, 4), padding='same', name='conv4')(x)
x = BatchNormalization(name='bn4')(x)
x = Activation('relu')(x)
x = MaxPooling2D()(x)

x = Dropout(0.5)(x)

x = Conv2D(512, (3, 3), padding='same', name='conv5')(x)
x = BatchNormalization(name='bn5')(x)
x = Activation('relu')(x)
x = Dense(1024, activation = 'relu', name='fc1')(x)
x = Dense(1024, activation = 'relu', name='fc2')(x)

# Deconvolution Layers (BatchNorm after non-linear activation)

x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv1')(x)
x = BatchNormalization(name='bn6')(x)
x = Activation('relu')(x)
x = UpSampling2D()(x)
x = Conv2DTranspose(256, (3, 3), padding='same', name='deconv2')(x)
x = BatchNormalization(name='bn7')(x)
x = Activation('relu')(x)
x = Conv2DTranspose(128, (3, 3), padding='same', name='deconv3')(x)
x = BatchNormalization(name='bn8')(x)
x = Activation('relu')(x)
x = UpSampling2D()(x)
x = Conv2DTranspose(1, (3, 3), padding='same', name='deconv4')(x)
x = BatchNormalization(name='bn9')(x)

x = Dropout(0.5)(x)

x = Activation('sigmoid')(x)
pred = Reshape((192,256))(x)

# %%
model_0 = Model(inputs=img_input, outputs=pred)
model_0.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance], metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_0.load_weights('fcn_1_epochs.h5')

# %%
print('\n~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_0.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_0.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_0.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 1 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 8ms/step
# ________________________
# IOU:       |   52.56  |
# Dice Coef: |   45.70  |
# Precision: |   31.46  |
# Recall:    |   86.70  |
# Accuracy:  |   34.39  |
# Loss:      |   47.44  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 1s 15ms/step
# ________________________
# IOU:       |   52.32  |
# Dice Coef: |   44.58  |
# Precision: |   30.76  |
# Recall:    |   85.40  |
# Accuracy:  |   34.45  |
# Loss:      |   47.68  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   51.92  |
# Dice Coef: |   44.53  |
# Precision: |   30.03  |
# Recall:    |   84.93  |
# Accuracy:  |   33.47  |
# Loss:      |   48.08  |
# ________________________

# %% [markdown]
# #### After 100 epochs

# %%
model, hist = fcn_net(epochs_num= 100, savename= 'fcn_100_epoch.h5')
# Out:
# Train on 360 samples, validate on 90 samples
# Epoch 1/100
# 360/360 [==============================] - 10s 27ms/step - loss: 0.2610 - iou: 0.7390 - dice_coef: 0.5012 - precision: 0.7191 - recall: 0.3859 - accuracy: 0.7372 - val_loss: 0.1630 - val_iou: 0.8370 - val_dice_coef: 0.7263 - val_precision: 0.7134 - val_recall: 0.8024 - val_accuracy: 0.8402
# Epoch 2/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2355 - iou: 0.7645 - dice_coef: 0.5295 - precision: 0.8149 - recall: 0.4064 - accuracy: 0.7772 - val_loss: 0.3838 - val_iou: 0.6162 - val_dice_coef: 0.5360 - val_precision: 0.3909 - val_recall: 0.9784 - val_accuracy: 0.5165
# Epoch 3/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2303 - iou: 0.7697 - dice_coef: 0.5360 - precision: 0.8550 - recall: 0.4010 - accuracy: 0.7831 - val_loss: 0.3384 - val_iou: 0.6616 - val_dice_coef: 0.5638 - val_precision: 0.4068 - val_recall: 0.9874 - val_accuracy: 0.5470
# Epoch 4/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2299 - iou: 0.7701 - dice_coef: 0.5419 - precision: 0.8241 - recall: 0.4115 - accuracy: 0.7805 - val_loss: 0.1803 - val_iou: 0.8197 - val_dice_coef: 0.5750 - val_precision: 0.8960 - val_recall: 0.6423 - val_accuracy: 0.8657
# Epoch 5/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2261 - iou: 0.7739 - dice_coef: 0.5446 - precision: 0.8599 - recall: 0.4068 - accuracy: 0.7857 - val_loss: 0.1733 - val_iou: 0.8267 - val_dice_coef: 0.6138 - val_precision: 0.6618 - val_recall: 0.8945 - val_accuracy: 0.8239
# Epoch 6/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2223 - iou: 0.7777 - dice_coef: 0.5560 - precision: 0.8552 - recall: 0.4228 - accuracy: 0.7895 - val_loss: 0.1785 - val_iou: 0.8215 - val_dice_coef: 0.6424 - val_precision: 0.6493 - val_recall: 0.9437 - val_accuracy: 0.8241
# Epoch 7/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2215 - iou: 0.7785 - dice_coef: 0.5536 - precision: 0.8733 - recall: 0.4146 - accuracy: 0.7898 - val_loss: 0.2496 - val_iou: 0.7504 - val_dice_coef: 0.5334 - val_precision: 0.5163 - val_recall: 0.7557 - val_accuracy: 0.7060
# Epoch 8/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2190 - iou: 0.7810 - dice_coef: 0.5618 - precision: 0.8732 - recall: 0.4239 - accuracy: 0.7927 - val_loss: 0.3603 - val_iou: 0.6397 - val_dice_coef: 0.4969 - val_precision: 0.3747 - val_recall: 0.8982 - val_accuracy: 0.5008
# Epoch 9/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2231 - iou: 0.7769 - dice_coef: 0.5558 - precision: 0.8593 - recall: 0.4131 - accuracy: 0.7861 - val_loss: 0.1488 - val_iou: 0.8512 - val_dice_coef: 0.6109 - val_precision: 0.9206 - val_recall: 0.6607 - val_accuracy: 0.8777
# Epoch 10/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2189 - iou: 0.7811 - dice_coef: 0.5625 - precision: 0.8713 - recall: 0.4251 - accuracy: 0.7925 - val_loss: 0.2264 - val_iou: 0.7736 - val_dice_coef: 0.5923 - val_precision: 0.5473 - val_recall: 0.8510 - val_accuracy: 0.7375
# Epoch 11/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2187 - iou: 0.7813 - dice_coef: 0.5600 - precision: 0.8814 - recall: 0.4205 - accuracy: 0.7923 - val_loss: 0.3561 - val_iou: 0.6439 - val_dice_coef: 0.5191 - val_precision: 0.3895 - val_recall: 0.8388 - val_accuracy: 0.5419
# Epoch 12/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2146 - iou: 0.7854 - dice_coef: 0.5717 - precision: 0.8917 - recall: 0.4275 - accuracy: 0.7971 - val_loss: 0.3177 - val_iou: 0.6823 - val_dice_coef: 0.5619 - val_precision: 0.4164 - val_recall: 0.9620 - val_accuracy: 0.5684
# Epoch 13/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2141 - iou: 0.7859 - dice_coef: 0.5698 - precision: 0.8984 - recall: 0.4276 - accuracy: 0.7983 - val_loss: 0.2142 - val_iou: 0.7858 - val_dice_coef: 0.5792 - val_precision: 0.5614 - val_recall: 0.8836 - val_accuracy: 0.7497
# Epoch 14/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2128 - iou: 0.7872 - dice_coef: 0.5733 - precision: 0.8955 - recall: 0.4345 - accuracy: 0.7993 - val_loss: 0.1281 - val_iou: 0.8719 - val_dice_coef: 0.6522 - val_precision: 0.8402 - val_recall: 0.8211 - val_accuracy: 0.8964
# Epoch 15/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2128 - iou: 0.7872 - dice_coef: 0.5780 - precision: 0.8845 - recall: 0.4405 - accuracy: 0.7995 - val_loss: 0.2449 - val_iou: 0.7551 - val_dice_coef: 0.5666 - val_precision: 0.5190 - val_recall: 0.9091 - val_accuracy: 0.7093
# Epoch 16/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2138 - iou: 0.7862 - dice_coef: 0.5720 - precision: 0.9061 - recall: 0.4220 - accuracy: 0.7979 - val_loss: 0.2840 - val_iou: 0.7160 - val_dice_coef: 0.5414 - val_precision: 0.4506 - val_recall: 0.8521 - val_accuracy: 0.6328
# Epoch 17/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2101 - iou: 0.7899 - dice_coef: 0.5824 - precision: 0.8968 - recall: 0.4433 - accuracy: 0.8026 - val_loss: 0.3169 - val_iou: 0.6831 - val_dice_coef: 0.4847 - val_precision: 0.3906 - val_recall: 0.8426 - val_accuracy: 0.5417
# Epoch 18/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2097 - iou: 0.7903 - dice_coef: 0.5814 - precision: 0.9120 - recall: 0.4356 - accuracy: 0.8031 - val_loss: 0.2453 - val_iou: 0.7547 - val_dice_coef: 0.5558 - val_precision: 0.5116 - val_recall: 0.8915 - val_accuracy: 0.7014
# Epoch 19/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2095 - iou: 0.7905 - dice_coef: 0.5808 - precision: 0.9141 - recall: 0.4362 - accuracy: 0.8034 - val_loss: 0.1431 - val_iou: 0.8569 - val_dice_coef: 0.5749 - val_precision: 0.9816 - val_recall: 0.6020 - val_accuracy: 0.8724
# Epoch 20/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2086 - iou: 0.7914 - dice_coef: 0.5863 - precision: 0.8956 - recall: 0.4481 - accuracy: 0.8040 - val_loss: 0.1535 - val_iou: 0.8465 - val_dice_coef: 0.6440 - val_precision: 0.8594 - val_recall: 0.8132 - val_accuracy: 0.8986
# Epoch 21/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2097 - iou: 0.7903 - dice_coef: 0.5832 - precision: 0.9072 - recall: 0.4358 - accuracy: 0.8024 - val_loss: 0.3400 - val_iou: 0.6600 - val_dice_coef: 0.5497 - val_precision: 0.3958 - val_recall: 0.9764 - val_accuracy: 0.5286
# Epoch 22/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2096 - iou: 0.7904 - dice_coef: 0.5833 - precision: 0.9092 - recall: 0.4366 - accuracy: 0.8028 - val_loss: 0.3068 - val_iou: 0.6932 - val_dice_coef: 0.5285 - val_precision: 0.4076 - val_recall: 0.9674 - val_accuracy: 0.5514
# Epoch 23/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2084 - iou: 0.7916 - dice_coef: 0.5844 - precision: 0.9097 - recall: 0.4417 - accuracy: 0.8042 - val_loss: 0.1649 - val_iou: 0.8351 - val_dice_coef: 0.6328 - val_precision: 0.6977 - val_recall: 0.8943 - val_accuracy: 0.8488
# Epoch 24/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2089 - iou: 0.7911 - dice_coef: 0.5872 - precision: 0.9082 - recall: 0.4393 - accuracy: 0.8037 - val_loss: 0.1783 - val_iou: 0.8217 - val_dice_coef: 0.6510 - val_precision: 0.6279 - val_recall: 0.9540 - val_accuracy: 0.8089
# Epoch 25/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2076 - iou: 0.7924 - dice_coef: 0.5876 - precision: 0.9186 - recall: 0.4383 - accuracy: 0.8052 - val_loss: 0.1140 - val_iou: 0.8860 - val_dice_coef: 0.6286 - val_precision: 0.8893 - val_recall: 0.8465 - val_accuracy: 0.9179
# Epoch 26/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2056 - iou: 0.7944 - dice_coef: 0.5936 - precision: 0.9130 - recall: 0.4501 - accuracy: 0.8076 - val_loss: 0.1626 - val_iou: 0.8374 - val_dice_coef: 0.5899 - val_precision: 0.7355 - val_recall: 0.8969 - val_accuracy: 0.8672
# Epoch 27/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2070 - iou: 0.7930 - dice_coef: 0.5905 - precision: 0.9091 - recall: 0.4448 - accuracy: 0.8058 - val_loss: 0.1696 - val_iou: 0.8304 - val_dice_coef: 0.6563 - val_precision: 0.6867 - val_recall: 0.8934 - val_accuracy: 0.8390
# Epoch 28/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2091 - iou: 0.7909 - dice_coef: 0.5881 - precision: 0.9025 - recall: 0.4410 - accuracy: 0.8031 - val_loss: 0.0987 - val_iou: 0.9013 - val_dice_coef: 0.7030 - val_precision: 0.9599 - val_recall: 0.7661 - val_accuracy: 0.9150
# Epoch 29/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2082 - iou: 0.7918 - dice_coef: 0.5881 - precision: 0.9148 - recall: 0.4402 - accuracy: 0.8045 - val_loss: 0.1261 - val_iou: 0.8739 - val_dice_coef: 0.6123 - val_precision: 0.9777 - val_recall: 0.6405 - val_accuracy: 0.8816
# Epoch 30/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2059 - iou: 0.7941 - dice_coef: 0.5924 - precision: 0.9136 - recall: 0.4473 - accuracy: 0.8072 - val_loss: 0.2802 - val_iou: 0.7198 - val_dice_coef: 0.5050 - val_precision: 0.4529 - val_recall: 0.8065 - val_accuracy: 0.6352
# Epoch 31/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2048 - iou: 0.7952 - dice_coef: 0.5955 - precision: 0.9146 - recall: 0.4500 - accuracy: 0.8081 - val_loss: 0.1982 - val_iou: 0.8018 - val_dice_coef: 0.5728 - val_precision: 0.6012 - val_recall: 0.8276 - val_accuracy: 0.7753
# Epoch 32/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2062 - iou: 0.7938 - dice_coef: 0.5932 - precision: 0.9161 - recall: 0.4450 - accuracy: 0.8063 - val_loss: 0.1583 - val_iou: 0.8417 - val_dice_coef: 0.6100 - val_precision: 0.7336 - val_recall: 0.8169 - val_accuracy: 0.8488
# Epoch 33/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2053 - iou: 0.7947 - dice_coef: 0.5934 - precision: 0.9136 - recall: 0.4488 - accuracy: 0.8073 - val_loss: 0.1874 - val_iou: 0.8126 - val_dice_coef: 0.4789 - val_precision: 0.9968 - val_recall: 0.3728 - val_accuracy: 0.8030
# Epoch 34/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2064 - iou: 0.7936 - dice_coef: 0.5914 - precision: 0.9095 - recall: 0.4471 - accuracy: 0.8062 - val_loss: 0.1436 - val_iou: 0.8564 - val_dice_coef: 0.6317 - val_precision: 0.9238 - val_recall: 0.7356 - val_accuracy: 0.8973
# Epoch 35/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2076 - iou: 0.7924 - dice_coef: 0.5869 - precision: 0.9203 - recall: 0.4396 - accuracy: 0.8047 - val_loss: 0.1058 - val_iou: 0.8942 - val_dice_coef: 0.7244 - val_precision: 0.8549 - val_recall: 0.8432 - val_accuracy: 0.9051
# Epoch 36/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2045 - iou: 0.7955 - dice_coef: 0.5969 - precision: 0.9186 - recall: 0.4492 - accuracy: 0.8084 - val_loss: 0.0940 - val_iou: 0.9060 - val_dice_coef: 0.7208 - val_precision: 0.9219 - val_recall: 0.8036 - val_accuracy: 0.9162
# Epoch 37/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2037 - iou: 0.7963 - dice_coef: 0.5992 - precision: 0.9165 - recall: 0.4533 - accuracy: 0.8095 - val_loss: 0.1129 - val_iou: 0.8871 - val_dice_coef: 0.6587 - val_precision: 0.9534 - val_recall: 0.7036 - val_accuracy: 0.8957
# Epoch 38/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2032 - iou: 0.7968 - dice_coef: 0.5982 - precision: 0.9279 - recall: 0.4497 - accuracy: 0.8102 - val_loss: 0.0994 - val_iou: 0.9006 - val_dice_coef: 0.6988 - val_precision: 0.8789 - val_recall: 0.8717 - val_accuracy: 0.9201
# Epoch 39/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2035 - iou: 0.7965 - dice_coef: 0.5976 - precision: 0.9217 - recall: 0.4532 - accuracy: 0.8098 - val_loss: 0.1438 - val_iou: 0.8562 - val_dice_coef: 0.6569 - val_precision: 0.7313 - val_recall: 0.9167 - val_accuracy: 0.8685
# Epoch 40/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2009 - iou: 0.7991 - dice_coef: 0.6052 - precision: 0.9282 - recall: 0.4575 - accuracy: 0.8129 - val_loss: 0.1093 - val_iou: 0.8907 - val_dice_coef: 0.6951 - val_precision: 0.8731 - val_recall: 0.8855 - val_accuracy: 0.9211
# Epoch 41/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2038 - iou: 0.7962 - dice_coef: 0.5982 - precision: 0.9185 - recall: 0.4521 - accuracy: 0.8095 - val_loss: 0.3115 - val_iou: 0.6885 - val_dice_coef: 0.5580 - val_precision: 0.4267 - val_recall: 0.9493 - val_accuracy: 0.5870
# Epoch 42/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2040 - iou: 0.7960 - dice_coef: 0.5960 - precision: 0.9251 - recall: 0.4489 - accuracy: 0.8090 - val_loss: 0.0792 - val_iou: 0.9208 - val_dice_coef: 0.7301 - val_precision: 0.9080 - val_recall: 0.8868 - val_accuracy: 0.9349
# Epoch 43/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2051 - iou: 0.7949 - dice_coef: 0.5955 - precision: 0.9096 - recall: 0.4513 - accuracy: 0.8074 - val_loss: 0.2201 - val_iou: 0.7799 - val_dice_coef: 0.4156 - val_precision: 0.9698 - val_recall: 0.2806 - val_accuracy: 0.7739
# Epoch 44/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2045 - iou: 0.7955 - dice_coef: 0.5967 - precision: 0.9290 - recall: 0.4459 - accuracy: 0.8089 - val_loss: 0.1012 - val_iou: 0.8988 - val_dice_coef: 0.6957 - val_precision: 0.8865 - val_recall: 0.7432 - val_accuracy: 0.8885
# Epoch 45/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2049 - iou: 0.7951 - dice_coef: 0.5965 - precision: 0.9151 - recall: 0.4503 - accuracy: 0.8082 - val_loss: 0.1457 - val_iou: 0.8543 - val_dice_coef: 0.6370 - val_precision: 0.7492 - val_recall: 0.7490 - val_accuracy: 0.8464
# Epoch 46/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2025 - iou: 0.7975 - dice_coef: 0.6006 - precision: 0.9284 - recall: 0.4536 - accuracy: 0.8112 - val_loss: 0.1248 - val_iou: 0.8752 - val_dice_coef: 0.6753 - val_precision: 0.7910 - val_recall: 0.8735 - val_accuracy: 0.8876
# Epoch 47/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2008 - iou: 0.7992 - dice_coef: 0.6053 - precision: 0.9326 - recall: 0.4561 - accuracy: 0.8131 - val_loss: 0.1452 - val_iou: 0.8548 - val_dice_coef: 0.6730 - val_precision: 0.6950 - val_recall: 0.9071 - val_accuracy: 0.8425
# Epoch 48/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2004 - iou: 0.7996 - dice_coef: 0.6057 - precision: 0.9285 - recall: 0.4600 - accuracy: 0.8135 - val_loss: 0.0773 - val_iou: 0.9227 - val_dice_coef: 0.7230 - val_precision: 0.9535 - val_recall: 0.8427 - val_accuracy: 0.9366
# Epoch 49/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2021 - iou: 0.7979 - dice_coef: 0.6034 - precision: 0.9191 - recall: 0.4581 - accuracy: 0.8112 - val_loss: 0.1285 - val_iou: 0.8715 - val_dice_coef: 0.6208 - val_precision: 0.9712 - val_recall: 0.6128 - val_accuracy: 0.8711
# Epoch 50/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2006 - iou: 0.7994 - dice_coef: 0.6074 - precision: 0.9334 - recall: 0.4566 - accuracy: 0.8135 - val_loss: 0.1304 - val_iou: 0.8696 - val_dice_coef: 0.6852 - val_precision: 0.7424 - val_recall: 0.9060 - val_accuracy: 0.8716
# Epoch 51/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2002 - iou: 0.7998 - dice_coef: 0.6058 - precision: 0.9322 - recall: 0.4573 - accuracy: 0.8135 - val_loss: 0.0860 - val_iou: 0.9140 - val_dice_coef: 0.7203 - val_precision: 0.9550 - val_recall: 0.8292 - val_accuracy: 0.9327
# Epoch 52/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2032 - iou: 0.7968 - dice_coef: 0.5963 - precision: 0.9203 - recall: 0.4550 - accuracy: 0.8101 - val_loss: 0.2090 - val_iou: 0.7910 - val_dice_coef: 0.6349 - val_precision: 0.5616 - val_recall: 0.9646 - val_accuracy: 0.7540
# Epoch 53/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1998 - iou: 0.8002 - dice_coef: 0.6068 - precision: 0.9287 - recall: 0.4610 - accuracy: 0.8141 - val_loss: 0.1999 - val_iou: 0.8001 - val_dice_coef: 0.6379 - val_precision: 0.5891 - val_recall: 0.9629 - val_accuracy: 0.7751
# Epoch 54/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1976 - iou: 0.8024 - dice_coef: 0.6135 - precision: 0.9384 - recall: 0.4635 - accuracy: 0.8166 - val_loss: 0.1353 - val_iou: 0.8647 - val_dice_coef: 0.6736 - val_precision: 0.7412 - val_recall: 0.9292 - val_accuracy: 0.8773
# Epoch 55/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1986 - iou: 0.8014 - dice_coef: 0.6120 - precision: 0.9385 - recall: 0.4600 - accuracy: 0.8155 - val_loss: 0.0781 - val_iou: 0.9219 - val_dice_coef: 0.7286 - val_precision: 0.9377 - val_recall: 0.8345 - val_accuracy: 0.9302
# Epoch 56/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1985 - iou: 0.8015 - dice_coef: 0.6096 - precision: 0.9302 - recall: 0.4652 - accuracy: 0.8157 - val_loss: 0.1237 - val_iou: 0.8763 - val_dice_coef: 0.7047 - val_precision: 0.7536 - val_recall: 0.9580 - val_accuracy: 0.8898
# Epoch 57/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2004 - iou: 0.7996 - dice_coef: 0.6081 - precision: 0.9300 - recall: 0.4576 - accuracy: 0.8130 - val_loss: 0.1439 - val_iou: 0.8561 - val_dice_coef: 0.6705 - val_precision: 0.7065 - val_recall: 0.9004 - val_accuracy: 0.8499
# Epoch 58/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1983 - iou: 0.8017 - dice_coef: 0.6120 - precision: 0.9306 - recall: 0.4648 - accuracy: 0.8157 - val_loss: 0.1685 - val_iou: 0.8315 - val_dice_coef: 0.6538 - val_precision: 0.6563 - val_recall: 0.9318 - val_accuracy: 0.8248
# Epoch 59/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2025 - iou: 0.7975 - dice_coef: 0.6011 - precision: 0.9366 - recall: 0.4490 - accuracy: 0.8107 - val_loss: 0.0576 - val_iou: 0.9424 - val_dice_coef: 0.7904 - val_precision: 0.9290 - val_recall: 0.8992 - val_accuracy: 0.9458
# Epoch 60/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1988 - iou: 0.8012 - dice_coef: 0.6109 - precision: 0.9326 - recall: 0.4630 - accuracy: 0.8154 - val_loss: 0.2317 - val_iou: 0.7683 - val_dice_coef: 0.5920 - val_precision: 0.5068 - val_recall: 0.9342 - val_accuracy: 0.6955
# Epoch 61/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.2004 - iou: 0.7996 - dice_coef: 0.6041 - precision: 0.9307 - recall: 0.4586 - accuracy: 0.8134 - val_loss: 0.1320 - val_iou: 0.8680 - val_dice_coef: 0.6907 - val_precision: 0.7734 - val_recall: 0.8836 - val_accuracy: 0.8813
# Epoch 62/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1994 - iou: 0.8006 - dice_coef: 0.6083 - precision: 0.9346 - recall: 0.4599 - accuracy: 0.8145 - val_loss: 0.2065 - val_iou: 0.7935 - val_dice_coef: 0.6255 - val_precision: 0.5619 - val_recall: 0.9350 - val_accuracy: 0.7526
# Epoch 63/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1976 - iou: 0.8024 - dice_coef: 0.6121 - precision: 0.9316 - recall: 0.4667 - accuracy: 0.8165 - val_loss: 0.1851 - val_iou: 0.8149 - val_dice_coef: 0.6430 - val_precision: 0.5991 - val_recall: 0.9305 - val_accuracy: 0.7849
# Epoch 64/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1972 - iou: 0.8028 - dice_coef: 0.6146 - precision: 0.9413 - recall: 0.4640 - accuracy: 0.8172 - val_loss: 0.1147 - val_iou: 0.8853 - val_dice_coef: 0.7020 - val_precision: 0.7940 - val_recall: 0.9181 - val_accuracy: 0.8985
# Epoch 65/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1996 - iou: 0.8004 - dice_coef: 0.6083 - precision: 0.9355 - recall: 0.4570 - accuracy: 0.8143 - val_loss: 0.1072 - val_iou: 0.8928 - val_dice_coef: 0.7092 - val_precision: 0.8420 - val_recall: 0.8928 - val_accuracy: 0.9135
# Epoch 66/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1986 - iou: 0.8014 - dice_coef: 0.6100 - precision: 0.9259 - recall: 0.4671 - accuracy: 0.8153 - val_loss: 0.1069 - val_iou: 0.8931 - val_dice_coef: 0.7256 - val_precision: 0.8037 - val_recall: 0.9468 - val_accuracy: 0.9105
# Epoch 67/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1968 - iou: 0.8032 - dice_coef: 0.6139 - precision: 0.9421 - recall: 0.4663 - accuracy: 0.8178 - val_loss: 0.1787 - val_iou: 0.8213 - val_dice_coef: 0.6643 - val_precision: 0.6198 - val_recall: 0.9700 - val_accuracy: 0.8030
# Epoch 68/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1978 - iou: 0.8022 - dice_coef: 0.6102 - precision: 0.9358 - recall: 0.4642 - accuracy: 0.8164 - val_loss: 0.2457 - val_iou: 0.7543 - val_dice_coef: 0.5988 - val_precision: 0.5028 - val_recall: 0.9694 - val_accuracy: 0.6921
# Epoch 69/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1984 - iou: 0.8016 - dice_coef: 0.6109 - precision: 0.9343 - recall: 0.4643 - accuracy: 0.8156 - val_loss: 0.0868 - val_iou: 0.9132 - val_dice_coef: 0.7175 - val_precision: 0.8913 - val_recall: 0.8684 - val_accuracy: 0.9245
# Epoch 70/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1974 - iou: 0.8026 - dice_coef: 0.6127 - precision: 0.9449 - recall: 0.4621 - accuracy: 0.8172 - val_loss: 0.0602 - val_iou: 0.9398 - val_dice_coef: 0.7771 - val_precision: 0.9554 - val_recall: 0.8705 - val_accuracy: 0.9452
# Epoch 71/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1971 - iou: 0.8029 - dice_coef: 0.6113 - precision: 0.9329 - recall: 0.4680 - accuracy: 0.8173 - val_loss: 0.0723 - val_iou: 0.9277 - val_dice_coef: 0.7717 - val_precision: 0.8676 - val_recall: 0.9483 - val_accuracy: 0.9377
# Epoch 72/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1975 - iou: 0.8025 - dice_coef: 0.6129 - precision: 0.9394 - recall: 0.4635 - accuracy: 0.8165 - val_loss: 0.1570 - val_iou: 0.8430 - val_dice_coef: 0.6833 - val_precision: 0.6483 - val_recall: 0.9718 - val_accuracy: 0.8251
# Epoch 73/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1981 - iou: 0.8019 - dice_coef: 0.6116 - precision: 0.9317 - recall: 0.4645 - accuracy: 0.8161 - val_loss: 0.0983 - val_iou: 0.9017 - val_dice_coef: 0.7203 - val_precision: 0.9261 - val_recall: 0.7474 - val_accuracy: 0.9012
# Epoch 74/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1970 - iou: 0.8030 - dice_coef: 0.6124 - precision: 0.9442 - recall: 0.4629 - accuracy: 0.8173 - val_loss: 0.0690 - val_iou: 0.9310 - val_dice_coef: 0.7528 - val_precision: 0.9173 - val_recall: 0.8906 - val_accuracy: 0.9398
# Epoch 75/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1967 - iou: 0.8033 - dice_coef: 0.6169 - precision: 0.9363 - recall: 0.4679 - accuracy: 0.8175 - val_loss: 0.2820 - val_iou: 0.7180 - val_dice_coef: 0.5891 - val_precision: 0.4628 - val_recall: 0.9506 - val_accuracy: 0.6405
# Epoch 76/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1951 - iou: 0.8049 - dice_coef: 0.6185 - precision: 0.9502 - recall: 0.4670 - accuracy: 0.8195 - val_loss: 0.0952 - val_iou: 0.9048 - val_dice_coef: 0.7426 - val_precision: 0.7997 - val_recall: 0.9545 - val_accuracy: 0.9107
# Epoch 77/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1955 - iou: 0.8045 - dice_coef: 0.6194 - precision: 0.9410 - recall: 0.4691 - accuracy: 0.8189 - val_loss: 0.1644 - val_iou: 0.8356 - val_dice_coef: 0.6774 - val_precision: 0.6354 - val_recall: 0.9787 - val_accuracy: 0.8179
# Epoch 78/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1964 - iou: 0.8036 - dice_coef: 0.6133 - precision: 0.9359 - recall: 0.4698 - accuracy: 0.8183 - val_loss: 0.2995 - val_iou: 0.7005 - val_dice_coef: 0.5712 - val_precision: 0.4404 - val_recall: 0.9535 - val_accuracy: 0.6077
# Epoch 79/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1972 - iou: 0.8028 - dice_coef: 0.6103 - precision: 0.9388 - recall: 0.4639 - accuracy: 0.8172 - val_loss: 0.1590 - val_iou: 0.8410 - val_dice_coef: 0.6839 - val_precision: 0.6657 - val_recall: 0.9423 - val_accuracy: 0.8324
# Epoch 80/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1975 - iou: 0.8025 - dice_coef: 0.6128 - precision: 0.9355 - recall: 0.4658 - accuracy: 0.8167 - val_loss: 0.0664 - val_iou: 0.9336 - val_dice_coef: 0.7756 - val_precision: 0.9590 - val_recall: 0.8516 - val_accuracy: 0.9410
# Epoch 81/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1961 - iou: 0.8039 - dice_coef: 0.6159 - precision: 0.9473 - recall: 0.4647 - accuracy: 0.8184 - val_loss: 0.1306 - val_iou: 0.8694 - val_dice_coef: 0.7062 - val_precision: 0.6974 - val_recall: 0.9450 - val_accuracy: 0.8538
# Epoch 82/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1955 - iou: 0.8045 - dice_coef: 0.6153 - precision: 0.9414 - recall: 0.4701 - accuracy: 0.8191 - val_loss: 0.1275 - val_iou: 0.8725 - val_dice_coef: 0.6251 - val_precision: 0.9719 - val_recall: 0.6032 - val_accuracy: 0.8696
# Epoch 83/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1944 - iou: 0.8056 - dice_coef: 0.6206 - precision: 0.9478 - recall: 0.4708 - accuracy: 0.8205 - val_loss: 0.3500 - val_iou: 0.6500 - val_dice_coef: 0.5347 - val_precision: 0.3919 - val_recall: 0.9488 - val_accuracy: 0.5236
# Epoch 84/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1947 - iou: 0.8053 - dice_coef: 0.6185 - precision: 0.9460 - recall: 0.4699 - accuracy: 0.8201 - val_loss: 0.1861 - val_iou: 0.8139 - val_dice_coef: 0.6420 - val_precision: 0.6178 - val_recall: 0.9092 - val_accuracy: 0.7943
# Epoch 85/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1953 - iou: 0.8047 - dice_coef: 0.6197 - precision: 0.9434 - recall: 0.4692 - accuracy: 0.8192 - val_loss: 0.1881 - val_iou: 0.8119 - val_dice_coef: 0.6699 - val_precision: 0.6052 - val_recall: 0.9713 - val_accuracy: 0.7908
# Epoch 86/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1981 - iou: 0.8019 - dice_coef: 0.6111 - precision: 0.9384 - recall: 0.4620 - accuracy: 0.8158 - val_loss: 0.1756 - val_iou: 0.8244 - val_dice_coef: 0.6736 - val_precision: 0.6121 - val_recall: 0.9493 - val_accuracy: 0.7955
# Epoch 87/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1974 - iou: 0.8026 - dice_coef: 0.6135 - precision: 0.9403 - recall: 0.4642 - accuracy: 0.8169 - val_loss: 0.1326 - val_iou: 0.8674 - val_dice_coef: 0.6868 - val_precision: 0.7252 - val_recall: 0.8683 - val_accuracy: 0.8545
# Epoch 88/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1975 - iou: 0.8025 - dice_coef: 0.6135 - precision: 0.9365 - recall: 0.4642 - accuracy: 0.8166 - val_loss: 0.2048 - val_iou: 0.7952 - val_dice_coef: 0.6523 - val_precision: 0.5513 - val_recall: 0.9341 - val_accuracy: 0.7431
# Epoch 89/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1964 - iou: 0.8036 - dice_coef: 0.6139 - precision: 0.9409 - recall: 0.4677 - accuracy: 0.8182 - val_loss: 0.2567 - val_iou: 0.7433 - val_dice_coef: 0.6174 - val_precision: 0.4869 - val_recall: 0.9792 - val_accuracy: 0.6724
# Epoch 90/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1944 - iou: 0.8056 - dice_coef: 0.6204 - precision: 0.9444 - recall: 0.4716 - accuracy: 0.8202 - val_loss: 0.0833 - val_iou: 0.9167 - val_dice_coef: 0.7437 - val_precision: 0.8888 - val_recall: 0.9240 - val_accuracy: 0.9400
# Epoch 91/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1947 - iou: 0.8053 - dice_coef: 0.6197 - precision: 0.9484 - recall: 0.4698 - accuracy: 0.8201 - val_loss: 0.0859 - val_iou: 0.9141 - val_dice_coef: 0.7616 - val_precision: 0.8357 - val_recall: 0.9592 - val_accuracy: 0.9269
# Epoch 92/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1959 - iou: 0.8041 - dice_coef: 0.6144 - precision: 0.9411 - recall: 0.4673 - accuracy: 0.8185 - val_loss: 0.0812 - val_iou: 0.9188 - val_dice_coef: 0.7592 - val_precision: 0.8743 - val_recall: 0.9408 - val_accuracy: 0.9388
# Epoch 93/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1957 - iou: 0.8043 - dice_coef: 0.6157 - precision: 0.9445 - recall: 0.4668 - accuracy: 0.8189 - val_loss: 0.0798 - val_iou: 0.9202 - val_dice_coef: 0.7394 - val_precision: 0.9041 - val_recall: 0.8689 - val_accuracy: 0.9296
# Epoch 94/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1943 - iou: 0.8057 - dice_coef: 0.6206 - precision: 0.9475 - recall: 0.4710 - accuracy: 0.8206 - val_loss: 0.1304 - val_iou: 0.8696 - val_dice_coef: 0.6904 - val_precision: 0.7757 - val_recall: 0.9434 - val_accuracy: 0.8968
# Epoch 95/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1940 - iou: 0.8060 - dice_coef: 0.6232 - precision: 0.9507 - recall: 0.4705 - accuracy: 0.8208 - val_loss: 0.2981 - val_iou: 0.7019 - val_dice_coef: 0.5762 - val_precision: 0.4343 - val_recall: 0.9772 - val_accuracy: 0.5961
# Epoch 96/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1944 - iou: 0.8056 - dice_coef: 0.6187 - precision: 0.9488 - recall: 0.4691 - accuracy: 0.8203 - val_loss: 0.1261 - val_iou: 0.8739 - val_dice_coef: 0.7081 - val_precision: 0.7371 - val_recall: 0.9620 - val_accuracy: 0.8804
# Epoch 97/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1941 - iou: 0.8059 - dice_coef: 0.6214 - precision: 0.9470 - recall: 0.4715 - accuracy: 0.8205 - val_loss: 0.1322 - val_iou: 0.8678 - val_dice_coef: 0.7087 - val_precision: 0.7189 - val_recall: 0.9734 - val_accuracy: 0.8723
# Epoch 98/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1940 - iou: 0.8060 - dice_coef: 0.6200 - precision: 0.9507 - recall: 0.4706 - accuracy: 0.8209 - val_loss: 0.0670 - val_iou: 0.9330 - val_dice_coef: 0.7678 - val_precision: 0.9033 - val_recall: 0.9597 - val_accuracy: 0.9546
# Epoch 99/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1931 - iou: 0.8069 - dice_coef: 0.6208 - precision: 0.9512 - recall: 0.4732 - accuracy: 0.8219 - val_loss: 0.1550 - val_iou: 0.8450 - val_dice_coef: 0.6743 - val_precision: 0.6895 - val_recall: 0.9785 - val_accuracy: 0.8538
# Epoch 100/100
# 360/360 [==============================] - 7s 19ms/step - loss: 0.1934 - iou: 0.8066 - dice_coef: 0.6208 - precision: 0.9524 - recall: 0.4713 - accuracy: 0.8215 - val_loss: 0.0818 - val_iou: 0.9182 - val_dice_coef: 0.7488 - val_precision: 0.8720 - val_recall: 0.9573 - val_accuracy: 0.9410

# %%
model_1 = Model(inputs=img_input, outputs=pred)
model_1.compile(optimizer= Adam(lr = 0.003), loss= [jaccard_distance], metrics=[iou, dice_coef, precision, recall, accuracy])

# %%
model_1.load_weights('fcn_100_epoch.h5')

# %% [markdown]
# Testing the statistics after 100 epochs

# %%
print('\n~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~')
print('\n-------------On Train Set--------------------------\n')
res = model_1.evaluate(x_train, y_train, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On Test  Set--------------------------\n')
res = model_1.evaluate(x_test, y_test, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
print('\n-------------On validation Set---------------------\n')
res = model_1.evaluate(x_val, y_val, batch_size= 18)
print('________________________')
print('IOU:       |   {:.2f}  |'.format(res[1]*100))
print('Dice Coef: |   {:.2f}  |'.format(res[2]*100))
print('Precision: |   {:.2f}  |'.format(res[3]*100))
print('Recall:    |   {:.2f}  |'.format(res[4]*100))
print('Accuracy:  |   {:.2f}  |'.format(res[5]*100))
print("Loss:      |   {:.2f}  |".format(res[0]*100))
print('________________________')
# Out:
# ~~~~~~~~~~~~~~~Stats after 100 epoch~~~~~~~~~~~~~~~~~~~
#
# -------------On Train Set--------------------------
#
# 360/360 [==============================] - 3s 8ms/step
# ________________________
# IOU:       |   92.51  |
# Dice Coef: |   75.74  |
# Precision: |   90.37  |
# Recall:    |   94.73  |
# Accuracy:  |   95.14  |
# Loss:      |   7.49  |
# ________________________
#
# -------------On Test  Set--------------------------
#
# 50/50 [==============================] - 0s 6ms/step
# ________________________
# IOU:       |   90.91  |
# Dice Coef: |   73.61  |
# Precision: |   82.90  |
# Recall:    |   94.47  |
# Accuracy:  |   92.38  |
# Loss:      |   9.09  |
# ________________________
#
# -------------On validation Set---------------------
#
# 90/90 [==============================] - 1s 7ms/step
# ________________________
# IOU:       |   91.82  |
# Dice Coef: |   74.88  |
# Precision: |   87.20  |
# Recall:    |   95.73  |
# Accuracy:  |   94.10  |
# Loss:      |   8.18  |
# ________________________

# %% [markdown]
# ### Plotting Training Statistics

# %%
plt.figure(figsize=(20, 7))
plt.suptitle('Training Statistics on Train Set')
plt.subplot(1,2,1)
plt.plot(hist.history['loss'], 'red')
plt.title('Loss')
plt.subplot(1,2,2)
plt.plot(hist.history['accuracy'], 'green')
plt.title('Accuracy')
plt.show()

# %% [markdown]
# ## Visualising Predicted Lesions

# %% [markdown]
# We have trained the model on the **training set**.
# We will make predictions on the unseen **test set**

# %%
img_num = 49
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 10
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 36
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 32
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 29
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %%
img_num = 21
img_pred = model_1.predict(x_test[img_num].reshape(1,192,256,3))
plt.figure(figsize=(16,16))
plt.subplot(1,3,1)
plt.imshow(x_test[img_num])
plt.title('Original Image')
plt.subplot(1,3,2)
plt.imshow(y_test[img_num], plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(1,3,3)
plt.imshow(img_pred.reshape(192, 256), plt.cm.binary_r)
plt.title('Predicted Output')
plt.show()

# %% [markdown]
# ## Final Enhance

# %% [markdown]
# * Currently the predicted outputs are blurry because the predicted pixel values are in the range 0 - 1.
# * To make clear edge preditions we can enhance our image by rounding up the pixel values to 1 which are > 0.5  .
# * While rounding down the pixel values to 0 which are < 0.5.
# * We can enhance the image to look for absolute shape predicted by ceiling and flooring the predicted values.

# %%
def enhance(img):
    sub = (model_1.predict(img.reshape(1,192,256,3))).flatten()

    for i in range(len(sub)):
        if sub[i] > 0.5:
            sub[i] = 1
        else:
            sub[i] = 0
    return sub

# %%
plt.figure(figsize=(12,12))
plt.suptitle('Comparing the Prediction after enhancement')
plt.subplot(3,2,1)
plt.imshow(y_test[21],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,2)
plt.imshow(enhance(x_test[21]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,3)
plt.imshow(y_test[47],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,4)
plt.imshow(enhance(x_test[47]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.subplot(3,2,5)
plt.imshow(y_test[36],plt.cm.binary_r)
plt.title('Ground Truth')
plt.subplot(3,2,6)
plt.imshow(enhance(x_test[36]).reshape(192,256), plt.cm.binary_r)
plt.title('Predicted')
plt.show()

# %% [markdown]
# * So we can observe that our results are very good on the Test dataset which suggests that the model is quite robust and well performing too.

# %% [markdown]
# ### **de nada!**
